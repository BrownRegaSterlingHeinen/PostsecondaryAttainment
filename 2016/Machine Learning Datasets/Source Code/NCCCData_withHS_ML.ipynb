# %% [markdown]
# # Create Community College Machine Learning Dataset
#
# This notebook reads in the merged data file located [here](https://github.com/BrownRegaSterlingHeinen/PostsecondaryAttainment/blob/master/RawDatasets/mergedData.xlsx) as input data. A lot of the code used in this notebook is from Dr. Jake Drew's repository for North Carolina public school data which can be viewed [here](https://github.com/jakemdrew/EducationDataNC/tree/master/2017/Machine%20Learning%20Datasets). This creates a dataset that is preprocessed for Machine Learning by going through the following transformations:
#
# - Columns that have the same value in every single row are deleted.
# - Nominal columns that have a unique value in every single row (all values are different) are deleted.
# - Empty columns (all values are NA or NULL) are deleted.
# - Numeric columns with more than the percentage of missing values specified by the missingThreshold parameter are deleted.
# - Remaining numeric columns with missing values are imputed / populated with the mean of the column.
# - Categorical / text based columns with > uniqueThreshold unique values are deleted.
# - Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
import pandas as pd
import numpy as np

# Load in merged community college data
url = 'https://github.com/BrownRegaSterlingHeinen/PostsecondaryAttainment/raw/master/2016/NCCC%20Datasets/mergedData_withHS.xlsx'
NCCCData = pd.read_excel(url)

# %%
# View info for data
NCCCData.info()
NCCCData.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 1950 entries, County to Lea_Name
# dtypes: float64(1168), int64(493), object(289)
# memory usage: 898.9+ KB
#       County                       College Name  \
# 0   Alamance         Alamance Community College
# 1   Beaufort  Beaufort County Community College
# 2     Bladen           Bladen Community College
# 3  Henderson       Blue Ridge Community College
# 4  Brunswick        Brunswick Community College
#
#   AdvESL_MeasureableSkills_Participant_POP_MSG  \
# 0                                       33.30%
# 1                                       25.00%
# 2                                            *
# 3                                        5.90%
# 4                                            *
#
#    AdvESL_MeasureableSkills_IndividualsServed  \
# 0                                        12.0
# 1                                         9.0
# 2                                         4.0
# 3                                        42.0
# 4                                         6.0
#
#    AdvESL_MeasureableSkills_Participants12+Hours  \
# 0                                           11.0
# 1                                            8.0
# 2                                            4.0
# 3                                           34.0
# 4                                            4.0
#
#   AdvESL_MeasureableSkills_ParticipServed  AdvESL_MeasureableSkills_POPs  \
# 0                                  91.70%                           12.0
# 1                                  88.90%                            8.0
# 2                                 100.00%                            4.0
# 3                                  81.00%                           34.0
# 4                                  66.70%                            4.0
#
#   AdvESL_MeasureableSkills_AHSGrad AdvESL_MeasureableSkills_HSE  \
# 0                            0.00%                        0.00%
# 1                            0.00%                        0.00%
# 2                                *                            *
# 3                            0.00%                        0.00%
# 4                                *                            *
#
#   AdvESL_MeasureableSkills_Postsecondary\nEnrollment  \
# 0                                              8.30%
# 1                                              0.00%
# 2                                                  *
# 3                                              0.00%
# 4                                                  *
#
#               ...              SPG Grade_A SPG Grade_A+NG SPG Grade_B  \
# 0             ...                 0.015657       0.000000    0.000000
# 1             ...                 0.109143       0.000000    0.000000
# 2             ...                 0.000000       0.000000    0.000000
# 3             ...                 0.047871       0.000000    0.952129
# 4             ...                 0.000000       0.082145    0.645008
#
#    SPG Grade_C SPG Grade_D  SPG Grade_F EVAAS Growth Status_Exceeded  \
# 0     0.984343    0.000000          0.0                     0.516816
# 1     0.206798    0.684059          0.0                     0.109143
# 2     0.548252    0.451748          0.0                     0.000000
# 3     0.000000    0.000000          0.0                     0.775510
# 4     0.272847    0.000000          0.0                     1.000000
#
#    EVAAS Growth Status_Met EVAAS Growth Status_NotMet  \
# 0                 0.307625                   0.175558
# 1                 0.000000                   0.890857
# 2                 0.548252                   0.451748
# 3                 0.224490                   0.000000
# 4                 0.000000                   0.000000
#
#                       Lea_Name
# 0  Alamance-Burlington Schools
# 1      Beaufort County Schools
# 2        Bladen County Schools
# 3     Henderson County Schools
# 4     Brunswick County Schools
#
# [5 rows x 1950 columns]

# %%
# Missing Data Threshold (Per Column)
missingThreshold = 0.60

# Unique Value Threshold (Per Column)
# Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
# (each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

# %% [markdown]
# ## Prepare Consolidated Dataset for Machine Learning
# Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.

# %% [markdown]
# We can see that there are many columns that are meant to be floats that are listed as objects. We need to iteratively go through all of the columns and change these values.

# %%
for column in range(len(NCCCData.columns)): #loops through every column in the data set
    if NCCCData.iloc[:,column].isnull().sum() == 0: #these are the string columns that do not need to be changed
        print("Column ", column , "stayed the same")
        # If a column contains '-', it is not reading correctly, the following code deals with those columns
        for value in range(len(NCCCData)):
            if '%' in str(NCCCData.iloc[value,column]):
                NCCCData.iloc[value,column] = float(NCCCData.iloc[value,column].strip("%"))/100
                NCCCData.iloc[:,column] = pd.to_numeric(NCCCData.iloc[:,column], errors='ignore')
            elif NCCCData.iloc[value,column] == "-":
                NCCCData.iloc[value, column] = None
                NCCCData.iloc[:,column] = pd.to_numeric(NCCCData.iloc[:,column], errors='ignore')
    elif NCCCData.iloc[:,column].dtype == "object": #if the column is of type object (percentages)
        for value in range(len(NCCCData)):
            if pd.isnull(NCCCData.iloc[value,column]):
                continue
            elif "%" in NCCCData.iloc[value,column]: # one of the issues is percentages
                if ' ' in NCCCData.iloc[value,column]:
                    NCCCData.iloc[value,column] = NCCCData.iloc[value,column].split((' ', 1)[0])[0]
                NCCCData.iloc[value,column] = float(NCCCData.iloc[value,column].strip("%"))/100
            elif "," in NCCCData.iloc[value, column]: # another issues is commas
                NCCCData.iloc[value, column] = float(NCCCData.iloc[value, column].replace(",", ""))
            elif NCCCData.iloc[value,column] == "*":
                NCCCData.iloc[value, column] = None
            #elif NCCCData.iloc[value,column] == "-":
             #   NCCCData.iloc[value, column] = NCCCData.iloc[value, column].replace("-", "")
            else:
                continue
        print("Column ", column, "was changed to type numeric")
        NCCCData.iloc[:,column] = pd.to_numeric(NCCCData.iloc[:,column])
    else:
        print("Column", column, "stayed the same")
# Out:
# Column  0 stayed the same
# Column  1 stayed the same
# Column  2 was changed to type numeric
# Column 3 stayed the same
# Column 4 stayed the same
# Column  5 was changed to type numeric
# Column 6 stayed the same
# Column  7 was changed to type numeric
# Column  8 was changed to type numeric
# Column  9 was changed to type numeric
# Column  10 was changed to type numeric
# Column  11 was changed to type numeric
# Column  12 was changed to type numeric
# Column 13 stayed the same
# Column  14 was changed to type numeric
# Column 15 stayed the same
# Column  16 was changed to type numeric
# Column 17 stayed the same
# Column  18 was changed to type numeric
# Column 19 stayed the same
# Column  20 was changed to type numeric
# Column 21 stayed the same
# Column  22 was changed to type numeric
# Column 23 stayed the same
# Column  24 was changed to type numeric
# Column  25 was changed to type numeric
# Column  26 was changed to type numeric
# Column  27 was changed to type numeric
# Column 28 stayed the same
# Column  29 was changed to type numeric
# Column 30 stayed the same
# Column  31 was changed to type numeric
# Column 32 stayed the same
# Column  33 was changed to type numeric
# Column 34 stayed the same
# Column  35 was changed to type numeric
# Column 36 stayed the same
# Column  37 was changed to type numeric
# Column  38 was changed to type numeric
# Column 39 stayed the same
# Column 40 stayed the same
# Column  41 was changed to type numeric
# Column 42 stayed the same
# Column  43 was changed to type numeric
# Column  44 was changed to type numeric
# Column  45 was changed to type numeric
# Column  46 was changed to type numeric
# Column  47 was changed to type numeric
# Column  48 was changed to type numeric
# Column  49 was changed to type numeric
# Column 50 stayed the same
# Column 51 stayed the same
# Column  52 was changed to type numeric
# Column 53 stayed the same
# Column  54 was changed to type numeric
# Column  55 was changed to type numeric
# Column  56 was changed to type numeric
# Column  57 was changed to type numeric
# Column  58 was changed to type numeric
# Column  59 was changed to type numeric
# Column  60 was changed to type numeric
# Column 61 stayed the same
# Column 62 stayed the same
# Column  63 was changed to type numeric
# Column 64 stayed the same
# Column  65 was changed to type numeric
# Column  66 was changed to type numeric
# Column  67 was changed to type numeric
# Column  68 was changed to type numeric
# Column  69 was changed to type numeric
# Column  70 was changed to type numeric
# Column 71 stayed the same
# Column  72 was changed to type numeric
# Column 73 stayed the same
# Column  74 was changed to type numeric
# Column  75 was changed to type numeric
# Column  76 was changed to type numeric
# Column  77 was changed to type numeric
# Column  78 was changed to type numeric
# Column  79 was changed to type numeric
# Column  80 was changed to type numeric
# Column 81 stayed the same
# Column 82 stayed the same
# Column  83 was changed to type numeric
# Column  84 was changed to type numeric
# Column  85 was changed to type numeric
# Column  86 was changed to type numeric
# Column  87 was changed to type numeric
# Column  88 was changed to type numeric
# Column  89 was changed to type numeric
# Column 90 stayed the same
# Column  91 was changed to type numeric
# Column  92 was changed to type numeric
# Column  93 was changed to type numeric
# Column  94 was changed to type numeric
# Column  95 was changed to type numeric
# Column 96 stayed the same
# Column  97 was changed to type numeric
# Column 98 stayed the same
# Column  99 was changed to type numeric
# Column  100 was changed to type numeric
# Column  101 was changed to type numeric
# Column 102 stayed the same
# Column  103 was changed to type numeric
# Column 104 stayed the same
# Column  105 was changed to type numeric
# Column 106 stayed the same
# Column  107 was changed to type numeric
# Column 108 stayed the same
# Column  109 was changed to type numeric
# Column 110 stayed the same
# Column  111 was changed to type numeric
# Column 112 stayed the same
# Column  113 was changed to type numeric
# Column 114 stayed the same
# Column  115 was changed to type numeric
# Column 116 stayed the same
# Column  117 was changed to type numeric
# Column 118 stayed the same
# Column  119 was changed to type numeric
# Column 120 stayed the same
# Column  121 was changed to type numeric
# Column 122 stayed the same
# Column  123 was changed to type numeric
# Column  124 was changed to type numeric
# Column 125 stayed the same
# Column 126 stayed the same
# Column  127 was changed to type numeric
# Column 128 stayed the same
# Column  129 was changed to type numeric
# Column  130 was changed to type numeric
# Column  131 was changed to type numeric
# Column  132 was changed to type numeric
# Column  133 was changed to type numeric
# Column  134 was changed to type numeric
# Column  135 was changed to type numeric
# Column 136 stayed the same
# Column 137 stayed the same
# Column  138 was changed to type numeric
# Column 139 stayed the same
# Column  140 was changed to type numeric
# Column  141 was changed to type numeric
# Column  142 was changed to type numeric
# Column  143 was changed to type numeric
# Column  144 was changed to type numeric
# Column  145 was changed to type numeric
# Column  146 was changed to type numeric
# Column 147 stayed the same
# Column 148 stayed the same
# Column  149 was changed to type numeric
# Column 150 stayed the same
# Column  151 was changed to type numeric
# Column  152 was changed to type numeric
# Column  153 was changed to type numeric
# Column  154 was changed to type numeric
# Column  155 was changed to type numeric
# Column  156 was changed to type numeric
# Column  157 was changed to type numeric
# Column 158 stayed the same
# Column 159 stayed the same
# Column  160 was changed to type numeric
# Column 161 stayed the same
# Column  162 was changed to type numeric
# Column  163 was changed to type numeric
# Column  164 was changed to type numeric
# Column  165 was changed to type numeric
# Column  166 was changed to type numeric
# Column  167 was changed to type numeric
# Column 168 stayed the same
# Column  169 was changed to type numeric
# Column  170 was changed to type numeric
# Column  171 was changed to type numeric
# Column  172 was changed to type numeric
# Column 173 stayed the same
# Column  174 was changed to type numeric
# Column  175 was changed to type numeric
# Column  176 was changed to type numeric
# Column  177 was changed to type numeric
# Column 178 stayed the same
# Column  179 was changed to type numeric
# Column  180 was changed to type numeric
# Column  181 was changed to type numeric
# Column  182 was changed to type numeric
# Column 183 stayed the same
# Column  184 was changed to type numeric
# Column  185 was changed to type numeric
# Column  186 was changed to type numeric
# Column  187 was changed to type numeric
# Column 188 stayed the same
# Column  189 was changed to type numeric
# Column  190 was changed to type numeric
# Column  191 was changed to type numeric
# Column  192 was changed to type numeric
# Column 193 stayed the same
# Column  194 was changed to type numeric
# Column  195 was changed to type numeric
# Column  196 was changed to type numeric
# Column  197 was changed to type numeric
# Column 198 stayed the same
# Column  199 was changed to type numeric
# Column  200 was changed to type numeric
# Column  201 was changed to type numeric
# Column  202 was changed to type numeric
# Column 203 stayed the same
# Column  204 was changed to type numeric
# Column  205 was changed to type numeric
# Column  206 was changed to type numeric
# Column  207 was changed to type numeric
# Column 208 stayed the same
# Column  209 was changed to type numeric
# Column  210 was changed to type numeric
# Column  211 was changed to type numeric
# Column  212 was changed to type numeric
# Column 213 stayed the same
# Column  214 was changed to type numeric
# Column  215 was changed to type numeric
# Column  216 was changed to type numeric
# Column  217 was changed to type numeric
# Column 218 stayed the same
# Column  219 was changed to type numeric
# Column  220 was changed to type numeric
# Column  221 was changed to type numeric
# Column  222 was changed to type numeric
# Column 223 stayed the same
# Column  224 was changed to type numeric
# Column  225 was changed to type numeric
# Column  226 was changed to type numeric
# Column  227 was changed to type numeric
# Column 228 stayed the same
# Column  229 was changed to type numeric
# Column  230 was changed to type numeric
# Column  231 was changed to type numeric
# Column  232 was changed to type numeric
# Column 233 stayed the same
# Column  234 was changed to type numeric
# Column  235 was changed to type numeric
# Column  236 was changed to type numeric
# Column  237 was changed to type numeric
# Column 238 stayed the same
# Column  239 was changed to type numeric
# Column  240 was changed to type numeric
# Column  241 was changed to type numeric
# Column  242 was changed to type numeric
# Column 243 stayed the same
# Column  244 was changed to type numeric
# Column  245 was changed to type numeric
# Column  246 was changed to type numeric
# Column  247 was changed to type numeric
# Column 248 stayed the same
# Column  249 was changed to type numeric
# Column  250 was changed to type numeric
# Column  251 was changed to type numeric
# Column  252 was changed to type numeric
# Column 253 stayed the same
# Column  254 was changed to type numeric
# Column  255 was changed to type numeric
# Column  256 was changed to type numeric
# Column  257 was changed to type numeric
# Column 258 stayed the same
# Column  259 was changed to type numeric
# Column  260 was changed to type numeric
# Column  261 was changed to type numeric
# Column  262 was changed to type numeric
# Column 263 stayed the same
# Column  264 was changed to type numeric
# Column  265 was changed to type numeric
# Column  266 was changed to type numeric
# Column  267 was changed to type numeric
# Column 268 stayed the same
# Column  269 was changed to type numeric
# Column  270 was changed to type numeric
# Column  271 was changed to type numeric
# Column  272 was changed to type numeric
# Column 273 stayed the same
# Column  274 was changed to type numeric
# Column  275 was changed to type numeric
# Column  276 was changed to type numeric
# Column  277 was changed to type numeric
# Column 278 stayed the same
# Column  279 was changed to type numeric
# Column  280 was changed to type numeric
# Column  281 was changed to type numeric
# Column  282 was changed to type numeric
# Column  283 was changed to type numeric
# Column 284 stayed the same
# Column 285 stayed the same
# Column  286 was changed to type numeric
# Column 287 stayed the same
# Column  288 was changed to type numeric
# Column  289 was changed to type numeric
# Column  290 was changed to type numeric
# Column  291 was changed to type numeric
# Column  292 was changed to type numeric
# Column  293 was changed to type numeric
# Column  294 was changed to type numeric
# Column 295 stayed the same
# Column 296 stayed the same
# Column  297 was changed to type numeric
# Column 298 stayed the same
# Column  299 was changed to type numeric
# Column  300 was changed to type numeric
# Column  301 was changed to type numeric
# Column  302 was changed to type numeric
# Column  303 was changed to type numeric
# Column  304 was changed to type numeric
# Column  305 was changed to type numeric
# Column 306 stayed the same
# Column 307 stayed the same
# Column  308 was changed to type numeric
# Column 309 stayed the same
# Column  310 was changed to type numeric
# Column  311 was changed to type numeric
# Column  312 was changed to type numeric
# Column  313 was changed to type numeric
# Column  314 was changed to type numeric
# Column  315 was changed to type numeric
# Column  316 was changed to type numeric
# Column 317 stayed the same
# Column 318 stayed the same
# Column  319 was changed to type numeric
# Column 320 stayed the same
# Column  321 was changed to type numeric
# Column  322 was changed to type numeric
# Column  323 was changed to type numeric
# Column  324 was changed to type numeric
# Column  325 was changed to type numeric
# Column  326 was changed to type numeric
# Column  327 was changed to type numeric
# Column  328 was changed to type numeric
# Column  329 was changed to type numeric
# Column  330 was changed to type numeric
# Column  331 was changed to type numeric
# Column  332 was changed to type numeric
# Column  333 was changed to type numeric
# Column 334 stayed the same
# Column 335 stayed the same
# Column 336 stayed the same
# Column 337 stayed the same
# Column 338 stayed the same
# Column 339 stayed the same
# Column 340 stayed the same
# Column  341 was changed to type numeric
# Column  342 was changed to type numeric
# Column  343 was changed to type numeric
# Column  344 was changed to type numeric
# Column 345 stayed the same
# Column 346 stayed the same
# Column 347 stayed the same
# Column  348 was changed to type numeric
# Column  349 was changed to type numeric
# Column  350 was changed to type numeric
# Column  351 was changed to type numeric
# Column 352 stayed the same
# Column  353 was changed to type numeric
# Column 354 stayed the same
# Column  355 was changed to type numeric
# Column  356 was changed to type numeric
# Column  357 was changed to type numeric
# Column 358 stayed the same
# Column  359 was changed to type numeric
# Column 360 stayed the same
# Column  361 was changed to type numeric
# Column  362 was changed to type numeric
# Column  363 was changed to type numeric
# Column 364 stayed the same
# Column  365 was changed to type numeric
# Column 366 stayed the same
# Column  367 was changed to type numeric
# Column 368 stayed the same
# Column  369 was changed to type numeric
# Column 370 stayed the same
# Column  371 was changed to type numeric
# Column 372 stayed the same
# Column  373 was changed to type numeric
# Column 374 stayed the same
# Column  375 was changed to type numeric
# Column  376 stayed the same
# Column  377 stayed the same
# Column  378 stayed the same
# Column  379 stayed the same
# Column  380 stayed the same
# Column  381 stayed the same
# Column  382 stayed the same
# Column  383 stayed the same
# Column  384 stayed the same
# Column  385 stayed the same
# Column  386 stayed the same
# Column  387 stayed the same
# Column  388 stayed the same
# Column  389 stayed the same
# Column  390 stayed the same
# Column  391 stayed the same
# Column  392 stayed the same
# Column  393 stayed the same
# Column  394 stayed the same
# Column  395 stayed the same
# Column  396 stayed the same
# Column  397 stayed the same
# Column  398 stayed the same
# Column  399 stayed the same
# Column  400 stayed the same
# Column  401 stayed the same
# Column  402 stayed the same
# Column 403 stayed the same
# Column 404 stayed the same
# Column 405 stayed the same
# Column 406 stayed the same
# Column 407 stayed the same
# Column 408 stayed the same
# Column  409 stayed the same
# Column  410 stayed the same
# Column  411 stayed the same
# Column  412 stayed the same
# Column  413 stayed the same
# Column  414 stayed the same
# Column  415 stayed the same
# Column  416 stayed the same
# Column  417 stayed the same
# Column 418 stayed the same
# Column 419 stayed the same
# Column 420 stayed the same
# Column 421 stayed the same
# Column 422 stayed the same
# Column  423 stayed the same
# Column  424 stayed the same
# Column  425 stayed the same
# Column  426 stayed the same
# Column  427 stayed the same
# Column  428 stayed the same
# Column  429 stayed the same
# Column  430 stayed the same
# Column  431 stayed the same
# Column  432 stayed the same
# Column  433 stayed the same
# Column  434 stayed the same
# Column  435 stayed the same
# Column  436 stayed the same
# Column  437 stayed the same
# Column  438 stayed the same
# Column  439 stayed the same
# Column  440 stayed the same
# Column  441 stayed the same
# Column  442 stayed the same
# Column  443 stayed the same
# Column 444 stayed the same
# Column  445 stayed the same
# Column  446 stayed the same
# Column  447 stayed the same
# Column  448 stayed the same
# Column  449 stayed the same
# Column  450 stayed the same
# Column  451 stayed the same
# Column  452 stayed the same
# Column  453 stayed the same
# Column  454 stayed the same
# Column  455 stayed the same
# Column  456 stayed the same
# Column  457 stayed the same
# Column  458 stayed the same
# Column  459 stayed the same
# Column  460 stayed the same
# Column  461 stayed the same
# Column  462 stayed the same
# Column  463 stayed the same
# Column  464 stayed the same
# Column  465 stayed the same
# Column  466 stayed the same
# Column  467 stayed the same
# Column  468 stayed the same
# Column  469 stayed the same
# Column  470 stayed the same
# Column  471 stayed the same
# Column  472 stayed the same
# Column  473 stayed the same
# Column  474 stayed the same
# Column  475 stayed the same
# Column  476 stayed the same
# Column  477 stayed the same
# Column  478 stayed the same
# Column  479 stayed the same
# Column  480 stayed the same
# Column  481 stayed the same
# Column 482 stayed the same
# Column 483 stayed the same
# Column 484 stayed the same
# Column 485 stayed the same
# Column 486 stayed the same
# Column 487 stayed the same
# Column 488 stayed the same
# Column 489 stayed the same
# Column 490 stayed the same
# Column 491 stayed the same
# Column 492 stayed the same
# Column 493 stayed the same
# Column 494 stayed the same
# Column 495 stayed the same
# Column 496 stayed the same
# Column 497 stayed the same
# Column 498 stayed the same
# Column 499 stayed the same
# Column 500 stayed the same
# Column 501 stayed the same
# Column 502 stayed the same
# Column 503 stayed the same
# Column 504 stayed the same
# Column 505 stayed the same
# Column 506 stayed the same
# Column 507 stayed the same
# Column 508 stayed the same
# Column 509 stayed the same
# Column 510 stayed the same
# Column 511 stayed the same
# Column 512 stayed the same
# Column 513 stayed the same
# Column 514 stayed the same
# Column 515 stayed the same
# Column 516 stayed the same
# Column 517 stayed the same
# Column 518 stayed the same
# Column 519 stayed the same
# Column 520 stayed the same
# Column 521 stayed the same
# Column 522 stayed the same
# Column 523 stayed the same
# Column 524 stayed the same
# Column 525 stayed the same
# Column 526 stayed the same
# Column 527 stayed the same
# Column 528 stayed the same
# Column 529 stayed the same
# Column 530 stayed the same
# Column 531 stayed the same
# Column 532 stayed the same
# Column 533 stayed the same
# Column 534 stayed the same
# Column 535 stayed the same
# Column 536 stayed the same
# Column 537 stayed the same
# Column 538 stayed the same
# Column 539 stayed the same
# Column 540 stayed the same
# Column 541 stayed the same
# Column 542 stayed the same
# Column 543 stayed the same
# Column 544 stayed the same
# Column 545 stayed the same
# Column 546 stayed the same
# Column 547 stayed the same
# Column 548 stayed the same
# Column 549 stayed the same
# Column 550 stayed the same
# Column 551 stayed the same
# Column 552 stayed the same
# Column 553 stayed the same
# Column 554 stayed the same
# Column 555 stayed the same
# Column 556 stayed the same
# Column 557 stayed the same
# Column 558 stayed the same
# Column 559 stayed the same
# Column 560 stayed the same
# Column 561 stayed the same
# Column 562 stayed the same
# Column 563 stayed the same
# Column 564 stayed the same
# Column 565 stayed the same
# Column 566 stayed the same
# Column 567 stayed the same
# Column 568 stayed the same
# Column 569 stayed the same
# Column 570 stayed the same
# Column 571 stayed the same
# Column 572 stayed the same
# Column 573 stayed the same
# Column 574 stayed the same
# Column 575 stayed the same
# Column 576 stayed the same
# Column 577 stayed the same
# Column 578 stayed the same
# Column 579 stayed the same
# Column 580 stayed the same
# Column 581 stayed the same
# Column 582 stayed the same
# Column 583 stayed the same
# Column 584 stayed the same
# Column 585 stayed the same
# Column 586 stayed the same
# Column 587 stayed the same
# Column 588 stayed the same
# Column 589 stayed the same
# Column 590 stayed the same
# Column 591 stayed the same
# Column 592 stayed the same
# Column 593 stayed the same
# Column 594 stayed the same
# Column 595 stayed the same
# Column 596 stayed the same
# Column 597 stayed the same
# Column 598 stayed the same
# Column 599 stayed the same
# Column 600 stayed the same
# Column 601 stayed the same
# Column 602 stayed the same
# Column 603 stayed the same
# Column 604 stayed the same
# Column 605 stayed the same
# Column 606 stayed the same
# Column 607 stayed the same
# Column 608 stayed the same
# Column 609 stayed the same
# Column 610 stayed the same
# Column 611 stayed the same
# Column 612 stayed the same
# Column 613 stayed the same
# Column 614 stayed the same
# Column 615 stayed the same
# Column 616 stayed the same
# Column 617 stayed the same
# Column 618 stayed the same
# Column 619 stayed the same
# Column 620 stayed the same
# Column 621 stayed the same
# Column 622 stayed the same
# Column 623 stayed the same
# Column 624 stayed the same
# Column 625 stayed the same
# Column 626 stayed the same
# Column 627 stayed the same
# Column 628 stayed the same
# Column 629 stayed the same
# Column 630 stayed the same
# Column 631 stayed the same
# Column 632 stayed the same
# Column 633 stayed the same
# Column 634 stayed the same
# Column 635 stayed the same
# Column 636 stayed the same
# Column 637 stayed the same
# Column 638 stayed the same
# Column 639 stayed the same
# Column 640 stayed the same
# Column 641 stayed the same
# Column 642 stayed the same
# Column 643 stayed the same
# Column 644 stayed the same
# Column 645 stayed the same
# Column 646 stayed the same
# Column 647 stayed the same
# Column 648 stayed the same
# Column 649 stayed the same
# Column 650 stayed the same
# Column 651 stayed the same
# Column 652 stayed the same
# Column 653 stayed the same
# Column 654 stayed the same
# Column 655 stayed the same
# Column 656 stayed the same
# Column 657 stayed the same
# Column 658 stayed the same
# Column 659 stayed the same
# Column 660 stayed the same
# Column 661 stayed the same
# Column 662 stayed the same
# Column 663 stayed the same
# Column 664 stayed the same
# Column 665 stayed the same
# Column 666 stayed the same
# Column 667 stayed the same
# Column 668 stayed the same
# Column 669 stayed the same
# Column 670 stayed the same
# Column 671 stayed the same
# Column 672 stayed the same
# Column 673 stayed the same
# Column 674 stayed the same
# Column 675 stayed the same
# Column 676 stayed the same
# Column 677 stayed the same
# Column 678 stayed the same
# Column 679 stayed the same
# Column 680 stayed the same
# Column 681 stayed the same
# Column 682 stayed the same
# Column 683 stayed the same
# Column 684 stayed the same
# Column 685 stayed the same
# Column 686 stayed the same
# Column 687 stayed the same
# Column 688 stayed the same
# Column 689 stayed the same
# Column 690 stayed the same
# Column 691 stayed the same
# Column 692 stayed the same
# Column 693 stayed the same
# Column 694 stayed the same
# Column 695 stayed the same
# Column 696 stayed the same
# Column 697 stayed the same
# Column 698 stayed the same
# Column 699 stayed the same
# Column 700 stayed the same
# Column 701 stayed the same
# Column 702 stayed the same
# Column 703 stayed the same
# Column 704 stayed the same
# Column 705 stayed the same
# Column 706 stayed the same
# Column 707 stayed the same
# Column 708 stayed the same
# Column 709 stayed the same
# Column 710 stayed the same
# Column 711 stayed the same
# Column 712 stayed the same
# Column 713 stayed the same
# Column 714 stayed the same
# Column 715 stayed the same
# Column 716 stayed the same
# Column 717 stayed the same
# Column 718 stayed the same
# Column 719 stayed the same
# Column 720 stayed the same
# Column  721 stayed the same
# Column  722 stayed the same
# Column  723 stayed the same
# Column  724 stayed the same
# Column  725 stayed the same
# Column  726 stayed the same
# Column  727 stayed the same
# Column  728 stayed the same
# Column  729 stayed the same
# Column  730 stayed the same
# Column  731 stayed the same
# Column  732 stayed the same
# Column  733 stayed the same
# Column  734 stayed the same
# Column  735 stayed the same
# Column  736 stayed the same
# Column  737 stayed the same
# Column  738 stayed the same
# Column  739 stayed the same
# Column  740 stayed the same
# Column  741 stayed the same
# Column  742 stayed the same
# Column  743 stayed the same
# Column  744 stayed the same
# Column  745 stayed the same
# Column  746 stayed the same
# Column  747 stayed the same
# Column  748 stayed the same
# Column  749 stayed the same
# Column  750 stayed the same
# Column  751 stayed the same
# Column  752 stayed the same
# Column  753 stayed the same
# Column  754 stayed the same
# Column  755 stayed the same
# Column  756 stayed the same
# Column  757 stayed the same
# Column  758 stayed the same
# Column  759 stayed the same
# Column  760 stayed the same
# Column  761 stayed the same
# Column  762 stayed the same
# Column  763 stayed the same
# Column  764 stayed the same
# Column  765 stayed the same
# Column  766 stayed the same
# Column  767 stayed the same
# Column  768 stayed the same
# Column  769 stayed the same
# Column  770 stayed the same
# Column  771 stayed the same
# Column  772 stayed the same
# Column  773 stayed the same
# Column  774 stayed the same
# Column  775 stayed the same
# Column  776 stayed the same
# Column  777 stayed the same
# Column  778 stayed the same
# Column  779 stayed the same
# Column  780 stayed the same
# Column  781 stayed the same
# Column  782 stayed the same
# Column  783 stayed the same
# Column  784 stayed the same
# Column  785 stayed the same
# Column  786 stayed the same
# Column  787 stayed the same
# Column  788 stayed the same
# Column  789 stayed the same
# Column  790 stayed the same
# Column  791 stayed the same
# Column  792 stayed the same
# Column  793 stayed the same
# Column  794 stayed the same
# Column  795 stayed the same
# Column  796 stayed the same
# Column  797 stayed the same
# Column  798 stayed the same
# Column  799 stayed the same
# Column  800 stayed the same
# Column  801 stayed the same
# Column  802 stayed the same
# Column  803 stayed the same
# Column  804 stayed the same
# Column  805 stayed the same
# Column  806 stayed the same
# Column  807 stayed the same
# Column  808 stayed the same
# Column  809 stayed the same
# Column  810 stayed the same
# Column  811 stayed the same
# Column  812 stayed the same
# Column  813 stayed the same
# Column  814 stayed the same
# Column  815 stayed the same
# Column  816 stayed the same
# Column  817 stayed the same
# Column  818 stayed the same
# Column  819 stayed the same
# Column  820 stayed the same
# Column  821 stayed the same
# Column  822 stayed the same
# Column  823 stayed the same
# Column  824 stayed the same
# Column  825 stayed the same
# Column  826 stayed the same
# Column  827 stayed the same
# Column  828 stayed the same
# Column  829 stayed the same
# Column  830 stayed the same
# Column  831 stayed the same
# Column  832 stayed the same
# Column  833 stayed the same
# Column  834 stayed the same
# Column  835 stayed the same
# Column  836 stayed the same
# Column  837 stayed the same
# Column  838 stayed the same
# Column  839 stayed the same
# Column  840 stayed the same
# Column  841 stayed the same
# Column  842 stayed the same
# Column  843 stayed the same
# Column  844 stayed the same
# Column  845 stayed the same
# Column  846 stayed the same
# Column  847 stayed the same
# Column  848 stayed the same
# Column  849 stayed the same
# Column  850 stayed the same
# Column  851 stayed the same
# Column  852 stayed the same
# Column  853 stayed the same
# Column  854 stayed the same
# Column  855 stayed the same
# Column  856 stayed the same
# Column  857 stayed the same
# Column  858 stayed the same
# Column  859 stayed the same
# Column  860 stayed the same
# Column  861 stayed the same
# Column  862 stayed the same
# Column  863 stayed the same
# Column  864 stayed the same
# Column  865 stayed the same
# Column  866 stayed the same
# Column  867 stayed the same
# Column  868 stayed the same
# Column  869 stayed the same
# Column  870 stayed the same
# Column  871 stayed the same
# Column  872 stayed the same
# Column  873 stayed the same
# Column  874 stayed the same
# Column  875 stayed the same
# Column  876 stayed the same
# Column  877 stayed the same
# Column  878 stayed the same
# Column  879 stayed the same
# Column  880 stayed the same
# Column  881 stayed the same
# Column  882 stayed the same
# Column  883 stayed the same
# Column  884 stayed the same
# Column  885 stayed the same
# Column  886 stayed the same
# Column  887 stayed the same
# Column  888 stayed the same
# Column  889 stayed the same
# Column  890 stayed the same
# Column  891 stayed the same
# Column  892 stayed the same
# Column  893 stayed the same
# Column  894 stayed the same
# Column  895 stayed the same
# Column  896 stayed the same
# Column  897 stayed the same
# Column  898 stayed the same
# Column  899 stayed the same
# Column  900 stayed the same
# Column  901 stayed the same
# Column  902 stayed the same
# Column  903 stayed the same
# Column  904 stayed the same
# Column  905 stayed the same
# Column  906 stayed the same
# Column  907 stayed the same
# Column  908 stayed the same
# Column  909 stayed the same
# Column  910 stayed the same
# Column  911 stayed the same
# Column  912 stayed the same
# Column  913 stayed the same
# Column  914 stayed the same
# Column  915 stayed the same
# Column  916 stayed the same
# Column  917 stayed the same
# Column  918 stayed the same
# Column  919 stayed the same
# Column  920 stayed the same
# Column  921 stayed the same
# Column  922 stayed the same
# Column  923 stayed the same
# Column  924 stayed the same
# Column  925 stayed the same
# Column  926 stayed the same
# Column  927 stayed the same
# Column  928 stayed the same
# Column  929 stayed the same
# Column  930 stayed the same
# Column  931 stayed the same
# Column  932 stayed the same
# Column  933 stayed the same
# Column  934 stayed the same
# Column  935 stayed the same
# Column  936 stayed the same
# Column  937 stayed the same
# Column  938 stayed the same
# Column  939 stayed the same
# Column  940 stayed the same
# Column  941 stayed the same
# Column  942 stayed the same
# Column  943 stayed the same
# Column  944 stayed the same
# Column  945 stayed the same
# Column  946 stayed the same
# Column  947 stayed the same
# Column  948 stayed the same
# Column  949 stayed the same
# Column  950 stayed the same
# Column  951 stayed the same
# Column  952 stayed the same
# Column  953 stayed the same
# Column  954 stayed the same
# Column  955 stayed the same
# Column  956 stayed the same
# Column  957 stayed the same
# Column  958 stayed the same
# Column  959 stayed the same
# Column  960 stayed the same
# Column  961 stayed the same
# Column  962 stayed the same
# Column  963 stayed the same
# Column  964 stayed the same
# Column  965 stayed the same
# Column  966 stayed the same
# Column  967 stayed the same
# Column  968 stayed the same
# Column  969 stayed the same
# Column  970 stayed the same
# Column  971 stayed the same
# Column  972 stayed the same
# Column  973 stayed the same
# Column  974 stayed the same
# Column  975 stayed the same
# Column  976 stayed the same
# Column  977 stayed the same
# Column  978 stayed the same
# Column  979 stayed the same
# Column  980 stayed the same
# Column  981 stayed the same
# Column  982 stayed the same
# Column  983 stayed the same
# Column  984 stayed the same
# Column  985 stayed the same
# Column  986 stayed the same
# Column  987 stayed the same
# Column  988 stayed the same
# Column  989 stayed the same
# Column  990 stayed the same
# Column  991 stayed the same
# Column  992 stayed the same
# Column  993 stayed the same
# Column  994 stayed the same
# Column  995 stayed the same
# Column  996 stayed the same
# Column  997 stayed the same
# Column  998 stayed the same
# Column  999 stayed the same
# Column  1000 stayed the same
# Column  1001 stayed the same
# Column  1002 stayed the same
# Column  1003 stayed the same
# Column  1004 stayed the same
# Column  1005 stayed the same
# Column  1006 stayed the same
# Column  1007 stayed the same
# Column  1008 stayed the same
# Column  1009 stayed the same
# Column  1010 stayed the same
# Column  1011 stayed the same
# Column  1012 stayed the same
# Column  1013 stayed the same
# Column  1014 stayed the same
# Column  1015 stayed the same
# Column  1016 stayed the same
# Column  1017 stayed the same
# Column  1018 stayed the same
# Column  1019 stayed the same
# Column  1020 stayed the same
# Column  1021 stayed the same
# Column  1022 stayed the same
# Column  1023 stayed the same
# Column  1024 stayed the same
# Column  1025 stayed the same
# Column  1026 stayed the same
# Column  1027 stayed the same
# Column  1028 stayed the same
# Column  1029 stayed the same
# Column  1030 stayed the same
# Column  1031 stayed the same
# Column  1032 stayed the same
# Column  1033 stayed the same
# Column  1034 stayed the same
# Column  1035 stayed the same
# Column  1036 stayed the same
# Column  1037 stayed the same
# Column  1038 stayed the same
# Column  1039 stayed the same
# Column  1040 stayed the same
# Column  1041 stayed the same
# Column  1042 stayed the same
# Column  1043 stayed the same
# Column  1044 stayed the same
# Column  1045 stayed the same
# Column  1046 stayed the same
# Column  1047 stayed the same
# Column  1048 stayed the same
# Column  1049 stayed the same
# Column  1050 stayed the same
# Column  1051 stayed the same
# Column  1052 stayed the same
# Column  1053 stayed the same
# Column  1054 stayed the same
# Column  1055 stayed the same
# Column  1056 stayed the same
# Column  1057 stayed the same
# Column  1058 stayed the same
# Column  1059 stayed the same
# Column  1060 stayed the same
# Column  1061 stayed the same
# Column  1062 stayed the same
# Column  1063 stayed the same
# Column  1064 stayed the same
# Column  1065 stayed the same
# Column  1066 stayed the same
# Column  1067 stayed the same
# Column  1068 stayed the same
# Column  1069 stayed the same
# Column  1070 stayed the same
# Column  1071 stayed the same
# Column  1072 stayed the same
# Column  1073 stayed the same
# Column  1074 stayed the same
# Column  1075 stayed the same
# Column  1076 stayed the same
# Column  1077 stayed the same
# Column  1078 stayed the same
# Column  1079 stayed the same
# Column  1080 stayed the same
# Column  1081 stayed the same
# Column  1082 stayed the same
# Column  1083 stayed the same
# Column  1084 stayed the same
# Column  1085 stayed the same
# Column  1086 stayed the same
# Column  1087 stayed the same
# Column  1088 stayed the same
# Column  1089 stayed the same
# Column  1090 stayed the same
# Column  1091 stayed the same
# Column  1092 stayed the same
# Column  1093 stayed the same
# Column  1094 stayed the same
# Column  1095 stayed the same
# Column  1096 stayed the same
# Column  1097 stayed the same
# Column  1098 stayed the same
# Column  1099 stayed the same
# Column  1100 stayed the same
# Column  1101 stayed the same
# Column  1102 stayed the same
# Column  1103 stayed the same
# Column  1104 stayed the same
# Column  1105 stayed the same
# Column  1106 stayed the same
# Column  1107 stayed the same
# Column  1108 stayed the same
# Column  1109 stayed the same
# Column  1110 stayed the same
# Column  1111 stayed the same
# Column  1112 stayed the same
# Column  1113 stayed the same
# Column  1114 stayed the same
# Column  1115 stayed the same
# Column  1116 stayed the same
# Column  1117 stayed the same
# Column  1118 stayed the same
# Column  1119 stayed the same
# Column  1120 stayed the same
# Column  1121 stayed the same
# Column  1122 stayed the same
# Column  1123 stayed the same
# Column  1124 stayed the same
# Column  1125 stayed the same
# Column  1126 stayed the same
# Column  1127 stayed the same
# Column  1128 stayed the same
# Column  1129 stayed the same
# Column  1130 stayed the same
# Column  1131 stayed the same
# Column  1132 stayed the same
# Column  1133 stayed the same
# Column  1134 stayed the same
# Column  1135 stayed the same
# Column  1136 stayed the same
# Column  1137 stayed the same
# Column  1138 stayed the same
# Column  1139 stayed the same
# Column  1140 stayed the same
# Column  1141 stayed the same
# Column  1142 stayed the same
# Column  1143 stayed the same
# Column  1144 stayed the same
# Column  1145 stayed the same
# Column  1146 stayed the same
# Column  1147 stayed the same
# Column  1148 stayed the same
# Column  1149 stayed the same
# Column  1150 stayed the same
# Column  1151 stayed the same
# Column  1152 stayed the same
# Column  1153 stayed the same
# Column  1154 stayed the same
# Column  1155 stayed the same
# Column  1156 stayed the same
# Column  1157 stayed the same
# Column  1158 stayed the same
# Column  1159 stayed the same
# Column  1160 stayed the same
# Column  1161 stayed the same
# Column  1162 stayed the same
# Column  1163 stayed the same
# Column  1164 stayed the same
# Column  1165 stayed the same
# Column  1166 stayed the same
# Column  1167 stayed the same
# Column  1168 stayed the same
# Column  1169 stayed the same
# Column  1170 stayed the same
# Column  1171 stayed the same
# Column  1172 stayed the same
# Column  1173 stayed the same
# Column  1174 stayed the same
# Column  1175 stayed the same
# Column  1176 stayed the same
# Column  1177 stayed the same
# Column  1178 stayed the same
# Column  1179 stayed the same
# Column  1180 stayed the same
# Column  1181 stayed the same
# Column  1182 stayed the same
# Column  1183 stayed the same
# Column  1184 stayed the same
# Column  1185 stayed the same
# Column  1186 stayed the same
# Column  1187 stayed the same
# Column  1188 stayed the same
# Column  1189 stayed the same
# Column  1190 stayed the same
# Column  1191 stayed the same
# Column  1192 stayed the same
# Column  1193 stayed the same
# Column  1194 stayed the same
# Column  1195 stayed the same
# Column  1196 stayed the same
# Column  1197 stayed the same
# Column  1198 stayed the same
# Column  1199 stayed the same
# Column  1200 stayed the same
# Column  1201 stayed the same
# Column  1202 stayed the same
# Column  1203 stayed the same
# Column  1204 stayed the same
# Column  1205 stayed the same
# Column  1206 stayed the same
# Column  1207 stayed the same
# Column  1208 stayed the same
# Column  1209 stayed the same
# Column  1210 stayed the same
# Column  1211 stayed the same
# Column  1212 stayed the same
# Column  1213 stayed the same
# Column  1214 stayed the same
# Column  1215 stayed the same
# Column  1216 stayed the same
# Column  1217 stayed the same
# Column  1218 stayed the same
# Column  1219 stayed the same
# Column  1220 stayed the same
# Column  1221 stayed the same
# Column  1222 stayed the same
# Column  1223 stayed the same
# Column  1224 stayed the same
# Column  1225 stayed the same
# Column  1226 stayed the same
# Column  1227 stayed the same
# Column  1228 stayed the same
# Column  1229 stayed the same
# Column  1230 stayed the same
# Column  1231 stayed the same
# Column  1232 stayed the same
# Column  1233 stayed the same
# Column  1234 stayed the same
# Column  1235 stayed the same
# Column  1236 stayed the same
# Column  1237 stayed the same
# Column  1238 stayed the same
# Column  1239 stayed the same
# Column  1240 stayed the same
# Column  1241 stayed the same
# Column  1242 stayed the same
# Column  1243 stayed the same
# Column  1244 stayed the same
# Column  1245 stayed the same
# Column  1246 stayed the same
# Column  1247 stayed the same
# Column  1248 stayed the same
# Column  1249 stayed the same
# Column  1250 stayed the same
# Column  1251 stayed the same
# Column  1252 stayed the same
# Column  1253 stayed the same
# Column  1254 stayed the same
# Column  1255 stayed the same
# Column  1256 stayed the same
# Column  1257 stayed the same
# Column  1258 stayed the same
# Column  1259 stayed the same
# Column  1260 stayed the same
# Column  1261 stayed the same
# Column  1262 stayed the same
# Column  1263 stayed the same
# Column  1264 stayed the same
# Column  1265 stayed the same
# Column  1266 stayed the same
# Column  1267 stayed the same
# Column  1268 stayed the same
# Column  1269 stayed the same
# Column  1270 stayed the same
# Column  1271 stayed the same
# Column  1272 stayed the same
# Column  1273 stayed the same
# Column  1274 stayed the same
# Column  1275 stayed the same
# Column  1276 stayed the same
# Column  1277 stayed the same
# Column  1278 stayed the same
# Column  1279 stayed the same
# Column  1280 stayed the same
# Column  1281 stayed the same
# Column  1282 stayed the same
# Column  1283 stayed the same
# Column  1284 stayed the same
# Column  1285 stayed the same
# Column  1286 stayed the same
# Column  1287 stayed the same
# Column  1288 stayed the same
# Column  1289 stayed the same
# Column  1290 stayed the same
# Column  1291 stayed the same
# Column  1292 stayed the same
# Column  1293 stayed the same
# Column  1294 stayed the same
# Column  1295 stayed the same
# Column  1296 stayed the same
# Column  1297 stayed the same
# Column  1298 stayed the same
# Column  1299 stayed the same
# Column  1300 stayed the same
# Column  1301 stayed the same
# Column  1302 stayed the same
# Column  1303 stayed the same
# Column  1304 stayed the same
# Column  1305 stayed the same
# Column  1306 stayed the same
# Column  1307 stayed the same
# Column  1308 stayed the same
# Column  1309 stayed the same
# Column  1310 stayed the same
# Column  1311 stayed the same
# Column  1312 stayed the same
# Column  1313 stayed the same
# Column  1314 stayed the same
# Column  1315 stayed the same
# Column  1316 stayed the same
# Column  1317 stayed the same
# Column  1318 stayed the same
# Column  1319 stayed the same
# Column  1320 stayed the same
# Column  1321 stayed the same
# Column  1322 stayed the same
# Column  1323 stayed the same
# Column  1324 stayed the same
# Column  1325 stayed the same
# Column  1326 stayed the same
# Column  1327 stayed the same
# Column  1328 stayed the same
# Column  1329 stayed the same
# Column  1330 stayed the same
# Column  1331 stayed the same
# Column  1332 stayed the same
# Column  1333 stayed the same
# Column  1334 stayed the same
# Column  1335 stayed the same
# Column  1336 stayed the same
# Column  1337 stayed the same
# Column  1338 stayed the same
# Column  1339 stayed the same
# Column  1340 stayed the same
# Column  1341 stayed the same
# Column  1342 stayed the same
# Column  1343 stayed the same
# Column  1344 stayed the same
# Column  1345 stayed the same
# Column  1346 stayed the same
# Column  1347 stayed the same
# Column  1348 stayed the same
# Column  1349 stayed the same
# Column  1350 stayed the same
# Column  1351 stayed the same
# Column  1352 stayed the same
# Column  1353 stayed the same
# Column  1354 stayed the same
# Column  1355 stayed the same
# Column  1356 stayed the same
# Column  1357 stayed the same
# Column  1358 stayed the same
# Column  1359 stayed the same
# Column  1360 stayed the same
# Column  1361 stayed the same
# Column  1362 stayed the same
# Column  1363 stayed the same
# Column  1364 stayed the same
# Column  1365 stayed the same
# Column  1366 stayed the same
# Column  1367 stayed the same
# Column  1368 stayed the same
# Column  1369 stayed the same
# Column  1370 stayed the same
# Column  1371 stayed the same
# Column  1372 stayed the same
# Column  1373 stayed the same
# Column  1374 stayed the same
# Column  1375 stayed the same
# Column  1376 stayed the same
# Column  1377 stayed the same
# Column  1378 stayed the same
# Column  1379 stayed the same
# Column  1380 stayed the same
# Column  1381 stayed the same
# Column  1382 stayed the same
# Column  1383 stayed the same
# Column  1384 stayed the same
# Column  1385 stayed the same
# Column  1386 stayed the same
# Column  1387 stayed the same
# Column  1388 stayed the same
# Column  1389 stayed the same
# Column  1390 stayed the same
# Column  1391 stayed the same
# Column  1392 stayed the same
# Column  1393 stayed the same
# Column  1394 stayed the same
# Column  1395 stayed the same
# Column  1396 stayed the same
# Column  1397 stayed the same
# Column  1398 stayed the same
# Column  1399 stayed the same
# Column  1400 stayed the same
# Column  1401 stayed the same
# Column  1402 stayed the same
# Column  1403 stayed the same
# Column  1404 stayed the same
# Column  1405 stayed the same
# Column  1406 stayed the same
# Column  1407 stayed the same
# Column  1408 stayed the same
# Column  1409 stayed the same
# Column  1410 stayed the same
# Column  1411 stayed the same
# Column  1412 stayed the same
# Column  1413 stayed the same
# Column  1414 stayed the same
# Column  1415 stayed the same
# Column  1416 stayed the same
# Column  1417 stayed the same
# Column  1418 stayed the same
# Column  1419 stayed the same
# Column  1420 stayed the same
# Column  1421 stayed the same
# Column  1422 stayed the same
# Column  1423 stayed the same
# Column  1424 stayed the same
# Column  1425 stayed the same
# Column  1426 stayed the same
# Column  1427 stayed the same
# Column  1428 stayed the same
# Column  1429 stayed the same
# Column  1430 stayed the same
# Column  1431 stayed the same
# Column  1432 stayed the same
# Column  1433 stayed the same
# Column  1434 stayed the same
# Column  1435 stayed the same
# Column  1436 stayed the same
# Column  1437 stayed the same
# Column  1438 stayed the same
# Column  1439 stayed the same
# Column  1440 stayed the same
# Column  1441 stayed the same
# Column  1442 stayed the same
# Column  1443 stayed the same
# Column  1444 stayed the same
# Column  1445 stayed the same
# Column  1446 stayed the same
# Column  1447 stayed the same
# Column  1448 stayed the same
# Column  1449 stayed the same
# Column  1450 stayed the same
# Column  1451 stayed the same
# Column  1452 stayed the same
# Column  1453 stayed the same
# Column  1454 stayed the same
# Column  1455 stayed the same
# Column  1456 stayed the same
# Column  1457 stayed the same
# Column  1458 stayed the same
# Column  1459 stayed the same
# Column  1460 stayed the same
# Column  1461 stayed the same
# Column  1462 stayed the same
# Column  1463 stayed the same
# Column  1464 stayed the same
# Column  1465 stayed the same
# Column  1466 stayed the same
# Column  1467 stayed the same
# Column  1468 stayed the same
# Column  1469 stayed the same
# Column  1470 stayed the same
# Column  1471 stayed the same
# Column  1472 stayed the same
# Column  1473 stayed the same
# Column  1474 stayed the same
# Column  1475 stayed the same
# Column  1476 stayed the same
# Column  1477 stayed the same
# Column  1478 stayed the same
# Column  1479 stayed the same
# Column  1480 stayed the same
# Column  1481 stayed the same
# Column  1482 stayed the same
# Column  1483 stayed the same
# Column  1484 stayed the same
# Column  1485 stayed the same
# Column  1486 stayed the same
# Column  1487 stayed the same
# Column  1488 stayed the same
# Column  1489 stayed the same
# Column  1490 stayed the same
# Column  1491 stayed the same
# Column  1492 stayed the same
# Column  1493 stayed the same
# Column  1494 stayed the same
# Column  1495 stayed the same
# Column  1496 stayed the same
# Column  1497 stayed the same
# Column  1498 stayed the same
# Column  1499 stayed the same
# Column  1500 stayed the same
# Column  1501 stayed the same
# Column  1502 stayed the same
# Column  1503 stayed the same
# Column  1504 stayed the same
# Column  1505 stayed the same
# Column  1506 stayed the same
# Column  1507 stayed the same
# Column  1508 stayed the same
# Column  1509 stayed the same
# Column  1510 stayed the same
# Column  1511 stayed the same
# Column  1512 stayed the same
# Column  1513 stayed the same
# Column  1514 stayed the same
# Column  1515 stayed the same
# Column  1516 stayed the same
# Column  1517 stayed the same
# Column  1518 stayed the same
# Column  1519 stayed the same
# Column  1520 stayed the same
# Column  1521 stayed the same
# Column  1522 stayed the same
# Column  1523 stayed the same
# Column  1524 stayed the same
# Column  1525 stayed the same
# Column  1526 stayed the same
# Column  1527 stayed the same
# Column  1528 stayed the same
# Column  1529 stayed the same
# Column  1530 stayed the same
# Column  1531 stayed the same
# Column  1532 stayed the same
# Column  1533 stayed the same
# Column  1534 stayed the same
# Column  1535 stayed the same
# Column  1536 stayed the same
# Column  1537 stayed the same
# Column  1538 stayed the same
# Column  1539 stayed the same
# Column  1540 stayed the same
# Column  1541 stayed the same
# Column  1542 stayed the same
# Column  1543 stayed the same
# Column  1544 stayed the same
# Column  1545 stayed the same
# Column  1546 stayed the same
# Column  1547 stayed the same
# Column  1548 stayed the same
# Column  1549 stayed the same
# Column  1550 stayed the same
# Column  1551 stayed the same
# Column  1552 stayed the same
# Column  1553 stayed the same
# Column  1554 stayed the same
# Column  1555 stayed the same
# Column  1556 stayed the same
# Column  1557 stayed the same
# Column  1558 stayed the same
# Column  1559 stayed the same
# Column  1560 stayed the same
# Column  1561 stayed the same
# Column  1562 stayed the same
# Column  1563 stayed the same
# Column  1564 stayed the same
# Column  1565 stayed the same
# Column  1566 stayed the same
# Column  1567 stayed the same
# Column  1568 stayed the same
# Column  1569 stayed the same
# Column  1570 stayed the same
# Column  1571 stayed the same
# Column  1572 stayed the same
# Column  1573 stayed the same
# Column  1574 stayed the same
# Column  1575 stayed the same
# Column  1576 stayed the same
# Column  1577 stayed the same
# Column  1578 stayed the same
# Column  1579 stayed the same
# Column  1580 stayed the same
# Column  1581 stayed the same
# Column  1582 stayed the same
# Column  1583 stayed the same
# Column  1584 stayed the same
# Column  1585 stayed the same
# Column  1586 stayed the same
# Column  1587 stayed the same
# Column  1588 stayed the same
# Column  1589 stayed the same
# Column  1590 stayed the same
# Column  1591 stayed the same
# Column  1592 stayed the same
# Column  1593 stayed the same
# Column  1594 stayed the same
# Column  1595 stayed the same
# Column  1596 stayed the same
# Column  1597 stayed the same
# Column  1598 stayed the same
# Column  1599 stayed the same
# Column  1600 stayed the same
# Column  1601 stayed the same
# Column  1602 stayed the same
# Column  1603 stayed the same
# Column  1604 stayed the same
# Column  1605 stayed the same
# Column  1606 stayed the same
# Column  1607 stayed the same
# Column  1608 stayed the same
# Column  1609 stayed the same
# Column  1610 stayed the same
# Column  1611 stayed the same
# Column  1612 stayed the same
# Column  1613 stayed the same
# Column  1614 stayed the same
# Column  1615 stayed the same
# Column  1616 stayed the same
# Column  1617 stayed the same
# Column  1618 stayed the same
# Column  1619 stayed the same
# Column  1620 stayed the same
# Column  1621 stayed the same
# Column  1622 stayed the same
# Column  1623 stayed the same
# Column  1624 stayed the same
# Column  1625 stayed the same
# Column  1626 stayed the same
# Column  1627 stayed the same
# Column  1628 stayed the same
# Column  1629 stayed the same
# Column  1630 stayed the same
# Column  1631 stayed the same
# Column  1632 stayed the same
# Column  1633 stayed the same
# Column  1634 stayed the same
# Column  1635 stayed the same
# Column  1636 stayed the same
# Column  1637 stayed the same
# Column  1638 stayed the same
# Column  1639 stayed the same
# Column  1640 stayed the same
# Column  1641 stayed the same
# Column  1642 stayed the same
# Column  1643 stayed the same
# Column  1644 stayed the same
# Column  1645 stayed the same
# Column  1646 stayed the same
# Column  1647 stayed the same
# Column  1648 stayed the same
# Column  1649 stayed the same
# Column  1650 stayed the same
# Column  1651 stayed the same
# Column  1652 stayed the same
# Column  1653 stayed the same
# Column  1654 stayed the same
# Column  1655 stayed the same
# Column  1656 stayed the same
# Column  1657 stayed the same
# Column  1658 stayed the same
# Column  1659 stayed the same
# Column  1660 stayed the same
# Column  1661 stayed the same
# Column  1662 stayed the same
# Column  1663 stayed the same
# Column  1664 stayed the same
# Column  1665 stayed the same
# Column  1666 stayed the same
# Column  1667 stayed the same
# Column  1668 stayed the same
# Column  1669 stayed the same
# Column  1670 stayed the same
# Column  1671 stayed the same
# Column  1672 stayed the same
# Column  1673 stayed the same
# Column  1674 stayed the same
# Column  1675 stayed the same
# Column  1676 stayed the same
# Column  1677 stayed the same
# Column  1678 stayed the same
# Column  1679 stayed the same
# Column  1680 stayed the same
# Column  1681 stayed the same
# Column  1682 stayed the same
# Column  1683 stayed the same
# Column  1684 stayed the same
# Column  1685 stayed the same
# Column  1686 stayed the same
# Column  1687 stayed the same
# Column  1688 stayed the same
# Column  1689 stayed the same
# Column  1690 stayed the same
# Column  1691 stayed the same
# Column  1692 stayed the same
# Column  1693 stayed the same
# Column  1694 stayed the same
# Column  1695 stayed the same
# Column  1696 stayed the same
# Column  1697 stayed the same
# Column  1698 stayed the same
# Column  1699 stayed the same
# Column  1700 stayed the same
# Column  1701 stayed the same
# Column  1702 stayed the same
# Column  1703 stayed the same
# Column  1704 stayed the same
# Column  1705 stayed the same
# Column  1706 stayed the same
# Column  1707 stayed the same
# Column  1708 stayed the same
# Column  1709 stayed the same
# Column  1710 stayed the same
# Column  1711 stayed the same
# Column  1712 stayed the same
# Column  1713 stayed the same
# Column  1714 stayed the same
# Column  1715 stayed the same
# Column  1716 stayed the same
# Column  1717 stayed the same
# Column  1718 stayed the same
# Column  1719 stayed the same
# Column  1720 stayed the same
# Column  1721 stayed the same
# Column  1722 stayed the same
# Column  1723 stayed the same
# Column  1724 stayed the same
# Column  1725 stayed the same
# Column  1726 stayed the same
# Column  1727 stayed the same
# Column  1728 stayed the same
# Column  1729 stayed the same
# Column  1730 stayed the same
# Column  1731 stayed the same
# Column  1732 stayed the same
# Column  1733 stayed the same
# Column  1734 stayed the same
# Column  1735 stayed the same
# Column  1736 stayed the same
# Column  1737 stayed the same
# Column  1738 stayed the same
# Column  1739 stayed the same
# Column  1740 stayed the same
# Column  1741 stayed the same
# Column  1742 stayed the same
# Column  1743 stayed the same
# Column  1744 stayed the same
# Column  1745 stayed the same
# Column  1746 stayed the same
# Column  1747 stayed the same
# Column  1748 stayed the same
# Column  1749 stayed the same
# Column  1750 stayed the same
# Column  1751 stayed the same
# Column  1752 stayed the same
# Column  1753 stayed the same
# Column  1754 stayed the same
# Column  1755 stayed the same
# Column  1756 stayed the same
# Column  1757 stayed the same
# Column  1758 stayed the same
# Column  1759 stayed the same
# Column  1760 stayed the same
# Column  1761 stayed the same
# Column  1762 stayed the same
# Column  1763 stayed the same
# Column  1764 stayed the same
# Column  1765 stayed the same
# Column  1766 stayed the same
# Column  1767 stayed the same
# Column  1768 stayed the same
# Column  1769 stayed the same
# Column  1770 stayed the same
# Column  1771 stayed the same
# Column  1772 stayed the same
# Column  1773 stayed the same
# Column  1774 stayed the same
# Column  1775 stayed the same
# Column  1776 stayed the same
# Column  1777 stayed the same
# Column  1778 stayed the same
# Column  1779 stayed the same
# Column  1780 stayed the same
# Column  1781 stayed the same
# Column  1782 stayed the same
# Column  1783 stayed the same
# Column  1784 stayed the same
# Column  1785 stayed the same
# Column  1786 stayed the same
# Column  1787 stayed the same
# Column  1788 stayed the same
# Column  1789 stayed the same
# Column  1790 stayed the same
# Column  1791 stayed the same
# Column  1792 stayed the same
# Column  1793 stayed the same
# Column  1794 stayed the same
# Column  1795 stayed the same
# Column  1796 stayed the same
# Column  1797 stayed the same
# Column  1798 stayed the same
# Column  1799 stayed the same
# Column  1800 stayed the same
# Column  1801 stayed the same
# Column  1802 stayed the same
# Column  1803 stayed the same
# Column  1804 stayed the same
# Column  1805 stayed the same
# Column  1806 stayed the same
# Column  1807 stayed the same
# Column  1808 stayed the same
# Column  1809 stayed the same
# Column  1810 stayed the same
# Column  1811 stayed the same
# Column  1812 stayed the same
# Column  1813 stayed the same
# Column  1814 stayed the same
# Column  1815 stayed the same
# Column  1816 stayed the same
# Column  1817 stayed the same
# Column  1818 stayed the same
# Column  1819 stayed the same
# Column  1820 stayed the same
# Column  1821 stayed the same
# Column  1822 stayed the same
# Column  1823 stayed the same
# Column  1824 stayed the same
# Column  1825 stayed the same
# Column  1826 stayed the same
# Column  1827 stayed the same
# Column  1828 stayed the same
# Column  1829 stayed the same
# Column  1830 stayed the same
# Column  1831 stayed the same
# Column  1832 stayed the same
# Column  1833 stayed the same
# Column  1834 stayed the same
# Column  1835 stayed the same
# Column  1836 stayed the same
# Column  1837 stayed the same
# Column  1838 stayed the same
# Column  1839 stayed the same
# Column  1840 stayed the same
# Column  1841 stayed the same
# Column  1842 stayed the same
# Column  1843 stayed the same
# Column  1844 stayed the same
# Column  1845 stayed the same
# Column  1846 stayed the same
# Column  1847 stayed the same
# Column  1848 stayed the same
# Column  1849 stayed the same
# Column  1850 stayed the same
# Column  1851 stayed the same
# Column  1852 stayed the same
# Column  1853 stayed the same
# Column  1854 stayed the same
# Column  1855 stayed the same
# Column  1856 stayed the same
# Column  1857 stayed the same
# Column  1858 stayed the same
# Column  1859 stayed the same
# Column  1860 stayed the same
# Column  1861 stayed the same
# Column  1862 stayed the same
# Column  1863 stayed the same
# Column  1864 stayed the same
# Column  1865 stayed the same
# Column  1866 stayed the same
# Column  1867 stayed the same
# Column  1868 stayed the same
# Column  1869 stayed the same
# Column  1870 stayed the same
# Column  1871 stayed the same
# Column  1872 stayed the same
# Column  1873 stayed the same
# Column  1874 stayed the same
# Column  1875 stayed the same
# Column  1876 stayed the same
# Column  1877 stayed the same
# Column  1878 stayed the same
# Column  1879 stayed the same
# Column  1880 stayed the same
# Column  1881 stayed the same
# Column  1882 stayed the same
# Column  1883 stayed the same
# Column  1884 stayed the same
# Column  1885 stayed the same
# Column  1886 stayed the same
# Column  1887 stayed the same
# Column  1888 stayed the same
# Column  1889 stayed the same
# Column  1890 stayed the same
# Column  1891 stayed the same
# Column  1892 stayed the same
# Column  1893 stayed the same
# Column  1894 stayed the same
# Column  1895 stayed the same
# Column  1896 stayed the same
# Column  1897 stayed the same
# Column  1898 stayed the same
# Column  1899 stayed the same
# Column  1900 stayed the same
# Column  1901 stayed the same
# Column  1902 stayed the same
# Column  1903 stayed the same
# Column  1904 stayed the same
# Column  1905 stayed the same
# Column  1906 stayed the same
# Column  1907 stayed the same
# Column  1908 stayed the same
# Column  1909 stayed the same
# Column  1910 stayed the same
# Column  1911 stayed the same
# Column  1912 stayed the same
# Column  1913 stayed the same
# Column  1914 stayed the same
# Column  1915 stayed the same
# Column  1916 stayed the same
# Column  1917 stayed the same
# Column  1918 stayed the same
# Column  1919 stayed the same
# Column  1920 stayed the same
# Column  1921 stayed the same
# Column  1922 stayed the same
# Column  1923 stayed the same
# Column  1924 stayed the same
# Column  1925 stayed the same
# Column  1926 stayed the same
# Column  1927 stayed the same
# Column  1928 stayed the same
# Column  1929 stayed the same
# Column  1930 stayed the same
# Column  1931 stayed the same
# Column  1932 stayed the same
# Column  1933 stayed the same
# Column  1934 stayed the same
# Column  1935 stayed the same
# Column  1936 stayed the same
# Column  1937 stayed the same
# Column  1938 stayed the same
# Column  1939 stayed the same
# Column  1940 stayed the same
# Column  1941 stayed the same
# Column  1942 stayed the same
# Column  1943 stayed the same
# Column  1944 stayed the same
# Column  1945 stayed the same
# Column  1946 stayed the same
# Column  1947 stayed the same
# Column  1948 stayed the same
# Column  1949 stayed the same

# %% [markdown]
# ### Remove Columns with Problematic Data
# Here we remove entire columns that could cause problems during machine learning. The following operations are performed:
#
# - Remove any columns that have the same value in every single row.
# - Remove any columns that have a unique value in every single row (all values are different).
# - Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = NCCCData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
NCCCData = NCCCData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
NCCCData.info(verbose=False)
print('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 1497 entries, County to Lea_Name
# dtypes: float64(1423), int64(71), object(3)
# memory usage: 690.1+ KB
#
# Columns Deleted:  453

# %%
#Remove any fields that have unique values in every row
NCCCDataRecordCt = NCCCData.shape[0]
UniqueValueCounts = NCCCData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == NCCCDataRecordCt].index
NCCCData = NCCCData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
NCCCData.info(verbose=False)
print('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 1472 entries, County to Lea_Name
# dtypes: float64(1423), int64(47), object(2)
# memory usage: 678.6+ KB
#
# Columns Deleted:  25

# %%
#Remove any empty fields (null values in every row)
NCCCDataRecordCt = NCCCData.shape[0]
NullValueCounts = NCCCData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == NCCCDataRecordCt].index
NCCCData = NCCCData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
NCCCData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 1472 entries, County to Lea_Name
# dtypes: float64(1423), int64(47), object(2)
# memory usage: 678.6+ KB
#
# Columns Deleted:  0

# %% [markdown]
# ### Handle Other Missing Values Types
# - Here we eliminate any numeric and continous columns with more than the percentage of missing values specified by the missingThreshold parameter.
# - All remaining missing values are populated with 0.

# %%
#Isolate continuous and categorical data types
#These are indexers into the NCCCData dataframe and may be used similar to the schoolData dataframe 
CCD_boolean = NCCCData.loc[:, (NCCCData.dtypes == bool) ]
CCD_nominal = NCCCData.loc[:, (NCCCData.dtypes == object)]
CCD_continuous = NCCCData.loc[:, (NCCCData.dtypes != bool) & (NCCCData.dtypes != object)]
print("Boolean Columns: ", CCD_boolean.shape[1])
print("Nominal Columns: ", CCD_nominal.shape[1])
print("Continuous Columns: ", CCD_continuous.shape[1])
print("Columns Accounted for: ", CCD_nominal.shape[1] + CCD_continuous.shape[1] + CCD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  2
# Continuous Columns:  1470
# Columns Accounted for:  1472

# %%
#Eliminate nominal columns with more than missingThreshold percentage of missing values
NCCCDataRecordCt = CCD_nominal.shape[0]
missingValueLimit = NCCCDataRecordCt * missingThreshold
NullValueCounts = CCD_nominal.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
NCCCData = NCCCData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
NCCCData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 1472 entries, County to Lea_Name
# dtypes: float64(1423), int64(47), object(2)
# memory usage: 678.6+ KB
#
# Columns Deleted:  0

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
NCCCDataRecordCt = CCD_continuous.shape[0]
missingValueLimit = NCCCDataRecordCt * missingThreshold
NullValueCounts = CCD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
NCCCData = NCCCData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
NCCCData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 1369 entries, County to Lea_Name
# dtypes: float64(1320), int64(47), object(2)
# memory usage: 631.1+ KB
#
# Columns Deleted:  103

# %%
#Eliminate continuous columns with more than Threshold percentage of 0 values
threshold = 0.40
NCCCDataRecordCt = NCCCData.shape[0]
zeroValueLimit = NCCCDataRecordCt * threshold
zeroValueCounts = pd.Series(np.count_nonzero(NCCCData, axis = 0))
zeroValueCols = zeroValueCounts[zeroValueCounts <= zeroValueLimit].index

newData = NCCCData.drop(NCCCData.columns[zeroValueCols], axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= 60% of 0 values******')
newData.info(verbose=False)
print('\r\nColumns Deleted: ', len(zeroValueCols))
# Out:
# *********After: Removing columns with >= 60% of 0 values******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 963 entries, County to Lea_Name
# dtypes: float64(916), int64(45), object(2)
# memory usage: 444.0+ KB
#
# Columns Deleted:  406

# %% [markdown]
# ### Impute any Remaining Missing Values with Mean Value
# Missing values will be imputed with the mean of the column.

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be Imputed with the Mean!*********')

#Check for Missing values 
missing_values = newData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be Imputed with the Mean!*********
#                                          Variable Name  Number Missing Values
# 1         AdvESL_MeasureableSkills_Participant_POP_MSG                     15
# 2           AdvESL_MeasureableSkills_IndividualsServed                      5
# 3        AdvESL_MeasureableSkills_Participants12+Hours                      5
# 4              AdvESL_MeasureableSkills_ParticipServed                      9
# 5                        AdvESL_MeasureableSkills_POPs                      5
# 6                         AdvESL_MeasureableSkills_HSE                     15
# 7    AdvESL_MeasureableSkills_Postsecondary\nEnroll...                     15
# 8                   AdvESL_MeasureableSkills_Post-test                     15
# 9                         AdvESL_MeasureableSkills_MSG                     15
# 10                                    Beg_ESL_Students                     17
# 11                                 LowBeg_ESL_Students                     12
# 12                              LowBeg_ESL_PCTProgress                     31
# 13                                HighBeg_ESL_Students                      8
# 14                             HighBeg_ESL_PCTProgress                     18
# 15                                 LowInt_ESL_Students                      7
# 16                              LowInt_ESL_PCTProgress                     16
# 17                                HighInt_ESL_Students                      7
# 18                             HighInt_ESL_PCTProgress                     18
# 19                               Advanced_ESL_Students                     10
# 20                            Advanced_ESL_PCTProgress                     19
# 21                Basic_Skills_Students\n(Denominator)                      5
# 22                 Basic_Skills_CompletingLevel\nLEVEL                      5
# 23                          Basic_Skills_PCTCompleting                      5
# 24                                Beg_ABE_Lit_Students                      5
# 25                             Beg_ABE_Lit_PCTProgress                     11
# 26                                Beg_BasicEd_Students                      5
# 27                             Beg_BasicEd_PCTProgress                      5
# 28                             LowInt_BasicEd_Students                      5
# 29                          LowInt_BasicEd_PCTProgress                      5
# 30                            HighInt_BasicEd_Students                      5
# 31                         HighInt_BasicEd_PCTProgress                      5
# 32                         Low_AdultSecondary_Students                      5
# 33                      Low_AdultSecondary_PCTProgress                      5
# 34                       BegABELit_Participant_POP_MSG                      6
# 35                         BegABELit_IndividualsServed                      5
# 36                     BegABELit_Participants12+ Hours                      5
# 37                           BegABELit_Particip/Served                      5
# 38                                      BegABELit_POPs                      5
# 39                                       BegABELit_HSE                      6
# 40                                  BegABELit_Posttest                      6
# 41                                       BegABELit_MSG                      6
# 42                      BegBasicEd_Participant_POP_MSG                      5
# 43                        BegBasicEd_IndividualsServed                      5
# 44                    BegBasicEd_Participants12+ Hours                      5
# 45                          BegBasicEd_Particip/Served                      5
# 46                                     BegBasicEd_POPs                      5
# 47                                      BegBasicEd_HSE                      5
# 48                            BegBasicEd_Postsecondary                      5
# 49                                 BegBasicEd_Posttest                      5
# 50                                      BegBasicEd_MSG                      5
# 51                       BegESLLit_Participant_POP_MSG                     35
# 52                         BegESLLit_IndividualsServed                      5
# 53                     BegESLLit_Participants12+ Hours                      5
# 54                           BegESLLit_Particip/Served                     14
# 55                                      BegESLLit_POPs                      5
# 56                                   BegESLLit_AHSGrad                     35
# 57                                       BegESLLit_HSE                     35
# 58                             BegESLLit_Postsecondary                     35
# 59                                BegESLLit_AHSCredits                     35
# 60                                  BegESLLit_Posttest                     35
# 61                                       BegESLLit_MSG                     35
# 62                           Transfer30+Hours_Students                      5
# 63                     Transfer30+Hours_PCTGreater2.25                      5
# 64                       TransferAssociateDeg_Students                      5
# 65              TransferAssociateDegree_PCTGreater2.25                      7
# 66                          Transfer_TotalStudents2016                      5
# 67                 TransferTotal_NumberGreater2.252016                      5
# 68                    TransferTotal_PCTGreater2.252016                      5
# 69                                        BASIC_SKILLS                      5
# 70                                          NON_OCC_SS                      7
# 71                                              OCC_RB                      5
# 72                                              OCC_SS                      5
# 73                          Annual_ConEd_USnBdCupCount                      5
# 74                      Annual Undup\n(Curr and ConEd)                      5
# 75                                          Unnamed: 1                      5
# 76                   12 HOURS ATTEMPTED\n(Denominator)                      5
# 77                    12 HOURS SUCCESSFUL\n(Numerator)                      5
# 78                                               16-17                      5
# 79                                               15-16                      5
# 80                                 % SUCCESSFUL\n14-15                      5
# 81                                               13-14                      5
# 82                                              13-Dec                      5
# 83                    NumStudents1stYearSuccess_Age-15                      5
# 84                            PCT1stYearSuccess_Age-15                     13
# 85                  NumStudents1stYearSuccess_Age16-17                      5
# 86                          PCT1stYearSuccess_Age16-17                      5
# 87                     NumStudents1stYearSuccess_Age18                      5
# 88                             PCT1stYearSuccess_Age18                      6
# 89                  NumStudents1stYearSuccess_Age19-24                      5
# 90                          PCT1stYearSuccess_Age19-24                      5
# 91                  NumStudents1stYearSuccess_Age25-39                      5
# 92                          PCT1stYearSuccess_Age25-39                      7
# 93                    NumStudents1stYearSuccess_Age40+                      5
# 94                            PCT1stYearSuccess_Age40+                     24
# 95                       AAF_1stYearSuccessNumStudents                      5
# 96                               AAF_1stYearSuccessPCT                     13
# 97                       AAM_1stYearSuccessNumStudents                      7
# 98                               AAM_1stYearSuccessPCT                     16
# 99                        CF_1stYearSuccessNumStudents                      5
# 100                               CF_1stYearSuccessPCT                      5
# 101                       CM_1stYearSuccessNumStudents                      5
# 102                               CM_1stYearSuccessPCT                      5
# 103                       HF_1stYearSuccessNumStudents                      6
# 104                               HF_1stYearSuccessPCT                     12
# 105                       HM_1stYearSuccessNumStudents                      6
# 106                               HM_1stYearSuccessPCT                     17
# 107                       OF_1stYearSuccessNumStudents                      5
# 108                               OF_1stYearSuccessPCT                     13
# 109                       OM_1stYearSuccessNumStudents                      6
# 110                               OM_1stYearSuccessPCT                     13
# 111                 HighAdultSecEd_Participant_POP_MSG                      6
# 112                   HighAdultSecEd_IndividualsServed                      5
# 113               HighAdultSecEd_Participants12+ Hours                      5
# 114                     HighAdultSecEd_Particip/Served                      5
# 115                                HighAdultSecEd_POPs                      5
# 116                             HighAdultSecEd_AHSGrad                      6
# 117                                 HighAdultSecEd_HSE                      6
# 118                       HighAdultSecEd_Postsecondary                      6
# 119                                 HighAdultSecEd_MSG                      6
# 120                     HighBegESL_Participant_POP_MSG                     13
# 121                       HighBegESL_IndividualsServed                      5
# 122                   HighBegESL_Participants12+ Hours                      5
# 123                         HighBegESL_Particip/Served                      7
# 124                                    HighBegESL_POPs                      5
# 125                                HighBegESL_Posttest                     13
# 126                                     HighBegESL_MSG                     13
# 127                 HighIntBasicEd_Participant_POP_MSG                      5
# 128                   HighIntBasicEd_IndividualsServed                      5
# 129               HighIntBasicEd_Participants12+ Hours                      5
# 130                     HighIntBasicEd_Particip/Served                      5
# 131                                HighIntBasicEd_POPs                      5
# 132                             HighIntBasicEd_AHSGrad                      5
# 133                                 HighIntBasicEd_HSE                      5
# 134                       HighIntBasicEd_Postsecondary                      5
# 135                            HighIntBasicEd_Posttest                      5
# 136                                 HighIntBasicEd_MSG                      5
# 137   HighInt_ESLMeasureableSkills_Participant_POP_MSG                     10
# 138     HighInt_ESLMeasureableSkills_IndividualsServed                      5
# 139  HighInt_ESLMeasureableSkills_Participants12+Hours                      5
# 140       HighInt_ESLMeasureableSkills_Particip/Served                      7
# 141                  HighInt_ESLMeasureableSkills_POPs                      5
# 142              HighInt_ESLMeasureableSkills_Posttest                     10
# 143                   HighInt_ESLMeasureableSkills_MSG                     10
# 144                            Cosmetology_NumTest2017                     15
# 145                         Cosmetology_PCTPassing2017                     22
# 146                         Cosmetology_PCTPassing2016                     25
# 147                         Cosmetology_PCTPassing2015                     29
# 148                         Cosmetology_PCTPassing2014                     29
# 149                                   Blet_NumTest2017                      5
# 150                                Blet_PCTPassing2017                      9
# 151                                Blet_PCTPassing2016                     11
# 152                                Blet_PCTPassing2015                     10
# 153                                Blet_PCTPassing2014                      8
# 154                       DetentionOfficer_NumTest2017                     29
# 155                    DetentionOfficer_PCTPassing2017                     29
# 156                    DetentionOfficer_PCTPassing2016                     33
# 157                               EMTBasic_NumTest2017                      6
# 158                            EMTBasic_PCTPassing2017                      8
# 159                            EMTBasic_PCTPassing2016                      7
# 160                            EMTBasic_PCTPassing2015                      5
# 161                            EMTBasic_PCTPassing2014                      7
# 162                           EMTParamedic_NumTest2017                     19
# 163                        EMTParamedic_PCTPassing2017                     28
# 164                        EMTParamedic_PCTPassing2015                     29
# 165                       PracticalNursing_NumTest2017                     25
# 166                    PracticalNursing_PCTPassing2017                     25
# 167                    PracticalNursing_PCTPassing2016                     29
# 168                      RegisteredNursing_NumTest2017                      8
# 169                   RegisteredNursing_PCTPassing2017                      8
# 170                   RegisteredNursing_PCTPassing2016                     18
# 171                   RegisteredNursing_PCTPassing2015                     14
# 172                   RegisteredNursing_PCTPassing2014                     14
# 173                  LowAdultSecEd_Participant_POP_MSG                      5
# 174                    LowAdultSecEd_IndividualsServed                      5
# 175                LowAdultSecEd_Participants12+ Hours                      5
# 176                      LowAdultSecEd_Particip/Served                      5
# 177                                 LowAdultSecEd_POPs                      5
# 178                              LowAdultSecEd_AHSGrad                      5
# 179                                  LowAdultSecEd_HSE                      5
# 180                        LowAdultSecEd_Postsecondary                      5
# 181                           LowAdultSecEd_AHSCredits                      5
# 182                             LowAdultSecEd_Posttest                      5
# 183                                  LowAdultSecEd_MSG                      5
# 184                      LowBegESL_Participant_POP_MSG                     24
# 185                        LowBegESL_IndividualsServed                      5
# 186                    LowBegESL_Participants12+ Hours                      5
# 187                          LowBegESL_Particip/Served                     12
# 188                                     LowBegESL_POPs                      5
# 189                                  LowBegESL_AHSGrad                     24
# 190                                      LowBegESL_HSE                     24
# 191                            LowBegESL_Postsecondary                     24
# 192                               LowBegESL_AHSCredits                     24
# 193                                 LowBegESL_Posttest                     24
# 194                                      LowBegESL_MSG                     24
# 195                  LowIntBasicEd_Participant_POP_MSG                      5
# 196                    LowIntBasicEd_IndividualsServed                      5
# 197                LowIntBasicEd_Participants12+ Hours                      5
# 198                      LowIntBasicEd_Particip/Served                      5
# 199                                 LowIntBasicEd_POPs                      5
# 200                              LowIntBasicEd_AHSGrad                      5
# 201                                  LowIntBasicEd_HSE                      5
# 202                        LowIntBasicEd_Postsecondary                      5
# 203                             LowIntBasicEd_Posttest                      5
# 204                                  LowIntBasicEd_MSG                      5
# 205                      LowIntESL_Participant_POP_MSG                     13
# 206                        LowIntESL_IndividualsServed                      5
# 207                LowIntESL_Participants\n(12+ Hours)                      5
# 208                          LowIntESL_Particip/Served                      7
# 209                                     LowIntESL_POPs                      5
# 210                                 LowIntESL_Posttest                     13
# 211                                      LowIntESL_MSG                     13
# 212                              Basic_Skills_Progress                      5
# 213                             Credit_English_Success                      5
# 214                                Credit_Math_Success                      5
# 215                             First_Year_Progression                      5
# 216                               Curr_Completion_Rate                      5
# 217                             Licensure_Passing_Rate                      5
# 218                               Transfer_Performance                      5
# 219                                               MEEL                      5
# 220                                              ACABE                      5
# 221                                              ABLBA                      5
# 222                                        FALL_COHORT                      5
# 223                                CRED_ENG_ENROLLMENT                      5
# 224                                 CREDIT_ENG_SUCCESS                      5
# 225                             ENG_PCT_Successful2015                      5
# 226                             ENG_PCT_Successful2014                      5
# 227                             ENG_PCT_Successful2013                      5
# 228                             ENG_PCT_Successful2012                      5
# 229                         FALL COHORT\n(Denominator)                      5
# 230                                CRED MAT ENROLLMENT                      5
# 231                    CREDIT MAT SUCCESS\n(Numerator)                      5
# 232                                               2015                      5
# 233                            % SUCCESSFUL\n2014 2013                      5
# 234                                         Unnamed: 6                      5
# 235                                               2012                      5
# 236                            English_Students_Age-15                      5
# 237                          English_SuccessPCT_Age-15                     11
# 238                          English_Students_Age16-17                      5
# 239                        English_SuccessPCT_Age16-17                      5
# 240                             English_Students_Age18                      5
# 241                           English_SuccessPCT_Age18                      5
# 242                          English_Students_Age19-24                      5
# 243                        English_SuccessPCT_Age19-24                      6
# 244                          English_Students_Age25-39                      5
# 245                        English_SuccessPCT_Age29-35                      6
# 246                            English_Students_Age40+                      6
# 247                          English_SuccessPCT_Age40+                     13
# 248                               Math_Students_Age-15                      5
# 249                             Math_SuccessPCT_Age-15                     11
# 250                             Math_Students_Age16-17                      5
# 251                           Math_SuccessPCT_Age16-17                      5
# 252                                Math_Students_Age18                      5
# 253                              Math_SuccessPCT_Age18                      5
# 254                             Math_Students_Age19-24                      5
# 255                           Math_SuccessPCT_Age19-24                      6
# 256                             Math_Students_Age25-39                      5
# 257                           Math_SuccessPCT_Age29-35                      6
# 258                               Math_Students_Age40+                      6
# 259                             Math_SuccessPCT_Age40+                     13
# 265                               AwardLess1Year_Total                      1
# 266                          AwardLess1Year_Men_Number                      1
# 267                         AwardLess1Year_Men_Percent                      1
# 268                        AwardLess1Year_Women_Number                      1
# 269                       AwardLess1Year_Women_Percent                      1
# 270                               AwardLess2Year_Total                      1
# 290                            InstitutionalGrants_Avg                      1
# 315                                   WhiteM_PCT086004                      2
# 316                                   WhiteM_PCT086017                      2
# 317                                   WhiteM_PCT086055                      2
# 318                                   WhiteM_PCT086090                      2
# 319                                   WhiteM_PCT086093                      2
# 320                                   AsianF_PCT086130                     28
# 321                                   AsianF_PCT086143                     28
# 322                                   AsianF_PCT086181                     28
# 323                                   AsianF_PCT086216                     28
# 324                                   AsianF_PCT086219                     28
# 325                                   AsianM_PCT086004                     28
# 326                                   AsianM_PCT086017                     28
# 327                                   AsianM_PCT086055                     28
# 328                                   AsianM_PCT086090                     28
# 329                                   AsianM_PCT086093                     28
# 330                                   BlackF_PCT086130                      4
# 331                                   BlackF_PCT086143                      4
# 332                                   BlackF_PCT086181                      4
# 333                                   BlackF_PCT086216                      4
# 334                                   BlackF_PCT086219                      4
# 335                                   BlackM_PCT086004                      4
# 336                                   BlackM_PCT086017                      4
# 337                                   BlackM_PCT086055                      4
# 338                                   BlackM_PCT086090                      4
# 339                                   BlackM_PCT086093                      4
# 340                                HispanicF_PCT086130                      5
# 341                                HispanicF_PCT086143                      5
# 342                                HispanicF_PCT086181                      5
# 343                                HispanicF_PCT086216                      5
# 344                                HispanicF_PCT086219                      5
# 345                                HispanicM_PCT086004                      5
# 346                                HispanicM_PCT086017                      5
# 347                                HispanicM_PCT086055                      5
# 348                                HispanicM_PCT086090                      5
# 349                                HispanicM_PCT086093                      5
# 350                                  IndianF_PCT086130                     28
# 351                                  IndianF_PCT086143                     28
# 352                                  IndianF_PCT086181                     28
# 353                                  IndianF_PCT086216                     28
# 354                                  IndianF_PCT086219                     28
# 355                                  IndianM_PCT086004                     28
# 356                                  IndianM_PCT086017                     28
# 357                                  IndianM_PCT086055                     28
# 358                                  IndianM_PCT086090                     28
# 359                                  IndianM_PCT086093                     28
# 360                                   OtherF_PCT086130                     12
# 361                                   OtherF_PCT086143                     12
# 362                                   OtherF_PCT086181                     12
# 363                                   OtherF_PCT086216                     12
# 364                                   OtherF_PCT086219                     12
# 365                                   OtherM_PCT086004                     12
# 366                                   OtherM_PCT086017                     12
# 367                                   OtherM_PCT086055                     12
# 368                                   OtherM_PCT086090                     12
# 369                                   OtherM_PCT086093                     12
# 370                                   TotalF_PCT086130                      2
# 371                                   TotalF_PCT086143                      2
# 372                                   TotalF_PCT086181                      2
# 373                                   TotalF_PCT086216                      2
# 374                                   TotalF_PCT086219                      2
# 375                                   TotalM_PCT086004                      2
# 376                                   TotalM_PCT086017                      2
# 377                                   TotalM_PCT086055                      2
# 378                                   TotalM_PCT086090                      2
# 379                                   TotalM_PCT086093                      2
# 380                                 TwoRaceF_PCT086130                     10
# 381                                 TwoRaceF_PCT086143                     10
# 382                                 TwoRaceF_PCT086181                     10
# 383                                 TwoRaceF_PCT086219                     10
# 384                                 TwoRaceM_PCT086004                     10
# 385                                 TwoRaceM_PCT086017                     10
# 386                                 TwoRaceM_PCT086055                     10
# 387                                 TwoRaceM_PCT086090                     10
# 388                                 TwoRaceM_PCT086093                     10
# 389                                   WhiteF_PCT086130                      2
# 390                                   WhiteF_PCT086143                      2
# 391                                   WhiteF_PCT086181                      2
# 392                                   WhiteF_PCT086216                      2
# 393                                   WhiteF_PCT086219                      2
# 394                                  Number of returns                      2
# 395                           Number of single returns                      2
# 396                            Number of joint returns                      2
# 397                Number of head of household returns                      2
# 398              Number with paid preparer's signature                      2
# 399                               Number of exemptions                      2
# 400                               Number of dependents                      2
# 401     Number of volunteer prepared returns [2]_Total                      2
# 402  Number of volunteer prepared returns [2]_Numbe...                      2
# 403  Number of volunteer prepared returns [2]_Numbe...                      2
# 404  Number of volunteer prepared returns [2]_Numbe...                      2
# 405         Number of refund anticipation loan returns                      2
# 406        Number of refund anticipation check returns                      2
# 407                      Number of elderly returns [3]                      2
# 408                    Adjusted gross income (AGI) [4]                      2
# 409                     Total income_Number of returns                      2
# 410                                Total income_Amount                      2
# 411        Salaries and wages in AGI_Number of returns                      2
# 412                   Salaries and wages in AGI_Amount                      2
# 413                 Taxable interest_Number of returns                      2
# 414                            Taxable interest_Amount                      2
# 415               Ordinary dividends_Number of returns                      2
# 416                          Ordinary dividends_Amount                      2
# 417          Qualified dividends [5]_Number of returns                      2
# 418                     Qualified dividends [5]_Amount                      2
# 419  State and local income tax refunds\n_Number of...                      2
# 420        State and local income tax refunds\n_Amount                      2
# 421  Business or profession\nnet income (less loss)...                      2
# 422  Business or profession\nnet income (less loss)...                      2
# 423  Net capital gain (less loss) in AGI_Number of ...                      2
# 424         Net capital gain (less loss) in AGI_Amount                      2
# 425  Taxable individual retirement\narrangement dis...                      2
# 426  Taxable individual retirement\narrangement dis...                      2
# 427    Pensions and annuities in AGI_Number of returns                      2
# 428               Pensions and annuities in AGI_Amount                      2
# 429                           Number of \nfarm returns                      2
# 430    Unemployment compensation [6]_Number of returns                      2
# 431               Unemployment compensation [6]_Amount                      2
# 432  Taxable Social Security benefits_Number of ret...                      2
# 433            Taxable Social Security benefits_Amount                      2
# 434  Partnership/S-corp net income (less loss)_Numb...                      2
# 435   Partnership/S-corp net income (less loss)_Amount                      2
# 436       Total statuory adjustments_Number of returns                      2
# 437                  Total statuory adjustments_Amount                      2
# 438                Educator expenses_Number of returns                      2
# 439                           Educator expenses_Amount                      2
# 440  Self-employed (Keogh) retirement plans_Number ...                      2
# 441      Self-employed (Keogh) retirement plans_Amount                      2
# 442  Self-employed health insurance deduction_Numbe...                      2
# 443    Self-employed health insurance deduction_Amount                      2
# 444  Individual retirement arrangement payments_Num...                      2
# 445  Individual retirement arrangement payments_Amount                      2
# 446  Student loan interest deduction_Number of returns                      2
# 447             Student loan interest deduction_Amount                      2
# 448       Tuition and fees deduction_Number of returns                      2
# 449                  Tuition and fees deduction_Amount                      2
# 450  Domestic production activities deduction_Numbe...                      2
# 451    Domestic production activities deduction_Amount                      2
# 452        Total itemized deductions_Number of returns                      2
# 453                   Total itemized deductions_Amount                      2
# 454            Total itemized deductions_Amount of AGI                      2
# 455  Total medical and dental \nexpenses deduction_...                      2
# 456  Total medical and dental \nexpenses deduction_...                      2
# 457     State and local income taxes_Number of returns                      2
# 458                State and local income taxes_Amount                      2
# 459  State and local general sales taxes_Number of ...                      2
# 460         State and local general sales taxes_Amount                      2
# 461                Real estate taxes_Number of returns                      2
# 462                           Real estate taxes_Amount                      2
# 463          Personal property taxes_Number of returns                      2
# 464                     Personal property taxes_Amount                      2
# 465                 Total taxes paid_Number of returns                      2
# 466                            Total taxes paid_Amount                      2
# 467     Home mortgage interest paid _Number of returns                      2
# 468                Home mortgage interest paid _Amount                      2
# 469  Home mortgage interest paid \nfrom personal se...                      2
# 470  Home mortgage interest paid \nfrom personal se...                      2
# 471                Deductible points_Number of returns                      2
# 472                           Deductible points_Amount                      2
# 473  Qualified mortgage insurance premiums_Number o...                      2
# 474       Qualified mortgage insurance premiums_Amount                      2
# 475         Investment interest paid_Number of returns                      2
# 476                    Investment interest paid_Amount                      2
# 477   Total charitable contributions_Number of returns                      2
# 478              Total charitable contributions_Amount                      2
# 479  Net limited miscellaneous deduction_Number of ...                      2
# 480         Net limited miscellaneous deduction_Amount                      2
# 481  Other non-limited \nmiscellaneous deduction_Nu...                      2
# 482  Other non-limited \nmiscellaneous deduction_Am...                      2
# 483                   Taxable income_Number of returns                      2
# 484                              Taxable income_Amount                      2
# 485        Income tax before credits_Number of returns                      2
# 486                   Income tax before credits_Amount                      2
# 487          Alternative minimum tax_Number of returns                      2
# 488                     Alternative minimum tax_Amount                      2
# 489  Excess advance \npremium tax credit repayment_...                      2
# 490  Excess advance \npremium tax credit repayment_...                      2
# 491                Total tax credits_Number of returns                      2
# 492                           Total tax credits_Amount                      2
# 493               Foreign tax credit_Number of returns                      2
# 494                          Foreign tax credit_Amount                      2
# 495  Child and dependent care credit_Number of returns                      2
# 496             Child and dependent care credit_Amount                      2
# 497   Nonrefundable education credit_Number of returns                      2
# 498              Nonrefundable education credit_Amount                      2
# 499  Retirement savings contributions credit_Number...                      2
# 500     Retirement savings contributions credit_Amount                      2
# 501                 Child tax credit_Number of returns                      2
# 502                            Child tax credit_Amount                      2
# 503    Residential energy tax credit_Number of returns                      2
# 504               Residential energy tax credit_Amount                      2
# 505              Self-employment tax_Number of returns                      2
# 506                         Self-employment tax_Amount                      2
# 507         Total premium tax credit_Number of returns                      2
# 508                    Total premium tax credit_Amount                      2
# 509       Advance premium tax credit_Number of returns                      2
# 510                  Advance premium tax credit_Amount                      2
# 511  Health care individual \nresponsibility paymen...                      2
# 512  Health care individual \nresponsibility paymen...                      2
# 513               Total tax payments_Number of returns                      2
# 514                          Total tax payments_Amount                      2
# 515         Earned income credit [7]_Number of returns                      2
# 516                    Earned income credit [7]_Amount                      2
# 517  Excess earned income credit \n(refundable) [8]...                      2
# 518  Excess earned income credit \n(refundable) [8]...                      2
# 519      Additional child tax credit_Number of returns                      2
# 520                 Additional child tax credit_Amount                      2
# 521      Refundable education credit_Number of returns                      2
# 522                 Refundable education credit_Amount                      2
# 523           Net premium tax credit_Number of returns                      2
# 524                      Net premium tax credit_Amount                      2
# 525                   Income tax [9]_Number of returns                      2
# 526                              Income tax [9]_Amount                      2
# 527         Total tax liability [10]_Number of returns                      2
# 528                    Total tax liability [10]_Amount                      2
# 529    Total additional Medicare tax_Number of returns                      2
# 530               Total additional Medicare tax_Amount                      2
# 531        Net investment income tax_Number of returns                      2
# 532                   Net investment income tax_Amount                      2
# 533   Tax due at time of filing [11]_Number of returns                      2
# 534              Tax due at time of filing [11]_Amount                      2
# 535       Overpayments refunded [12]_Number of returns                      2
# 536                  Overpayments refunded [12]_Amount                      2
# 537                 $1 under $25,000 Number of Returns                      2
# 538            $25,000 under $50,000 Number of Returns                      2
# 539            $50,000 under $75,000 Number of Returns                      2
# 540           $75,000 under $100,000 Number of Returns                      2
# 541          $100,000 under $200,000 Number of Returns                      2
# 542                 $200,000 or more Number of Returns                      2

# %%
#Replace all remaining NaN with mean of column
newData = newData.fillna(newData.mean())

#Check for Missing values after final imputation 
missing_values = newData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %%
#NCCCData = NCCCData.dropna(axis='columns', how='all')

# %% [markdown]
# ### Categorical Variables
# Any categorical variables that have greater than the set number of unique values, the uniqueThreshold, in each column will be deleted. Other categorical variables will be one-hot encoded.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = newData[CCD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
newData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
newData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 961 entries, AdvESL_MeasureableSkills_Participant_POP_MSG to EVAAS Growth Status_NotMet
# dtypes: float64(916), int64(45)
# memory usage: 443.0 KB
#
# Columns Deleted:  2

# %%
#Isolate remaining categorical variables
begColumnCt = len(newData.columns)
CCD_nominal = newData.loc[:, (newData.dtypes == object)]

#one hot encode categorical variables
if (len(CCD_nominal.columns) != 0):
    newData = pd.get_dummies(data=newData, 
                           columns=CCD_nominal, drop_first=True)
    #Determine change in column count
    endColumnCt = len(newData.columns)
    columnsAdded = endColumnCt - begColumnCt

    #Review dataset contents one hot high unique value drops
    print('Columns To One-Hot Encode: ', len(CCD_nominal.columns))
    print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
    newData.info(verbose=False)
    print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
else:
    print("No categorical variables to one-hot encode.")
# Out:
# No categorical variables to one-hot encode.

# %% [markdown]
# ### Identify and Remove Highly Correlated Features
# Find and remove any columns / features that are > 95% correlated

# %%
from IPython.core.display import display as d

pd.set_option("display.max_rows",None)

#set the value you want to see variable pairs correlation greater than
correlation_value=.95

#find the correlations of all variable pairs and sort it
#then take only those with correlation greater than value entered
so=pd.DataFrame(newData.corr().unstack().sort_values(kind="quicksort",ascending=False))
so.columns=["Correlation"]
pos=so[(so['Correlation']<1)&(so['Correlation']>correlation_value)].drop_duplicates()
neg=so[(so['Correlation']>-1)&(so['Correlation']<(-1*correlation_value))].drop_duplicates()

#print out results
if neg.shape[0]>0:
    print('Variables with negative correlation below threshold')
    print(len(neg))
    #d(neg)
else:    
    print('No variables with negative correlation below threshold')
    
print("")

if pos.shape[0]>0:
    print('Variables with positive correlation above threshold')
    print(len(pos))
    #d(pos)
else:
    print('No variables with positive correlation above threshold')
    
#create a list of variables to remove (just the left column from the correlations)
pos_list=[]
neg_list=[]

#create a list of the first variables in the pair for the pos and neg lists
if(len(pos)>0):
    pos['correlated_vars']=pos.index
    for i in range(len(pos)):
        pos_list.append(pos['correlated_vars'][i][1])
    
if(len(neg)>0):    
    neg['correlated_vars']=neg.index
    for i in range(len(neg)):
        neg_list.append(neg['correlated_vars'][i][1])

#remove duplicates from the lists
pos_list=set(pos_list)
neg_list=set(neg_list)

#create a list of variables that we want to drop from the data set
if(len(neg_list)>0&len(pos_list)>0):
    to_drop=pd.concat(pos_list,neg_list)
elif(len(neg_list)>0):
    to_drop=neg_list
else:
    to_drop=pos_list
    
#drop the variables in the to_drop list form the data set
newData = newData.drop(to_drop, axis=1)
# Out:
# Variables with negative correlation below threshold
# 129
#
# Variables with positive correlation above threshold
# 13109

# %%
#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
newData.info(verbose=False)

#Save the final dataset to a .csv file
newData.to_csv('NCCCData_withHS' + '_ML.csv', sep=',', index=False)
# Out:
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 927 entries, AdvESL_MeasureableSkills_Participant_POP_MSG to EVAAS Growth Status_NotMet
# dtypes: float64(882), int64(45)
# memory usage: 427.4 KB

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
newData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 927 columns):
# AdvESL_MeasureableSkills_Participant_POP_MSG                                                                  float64
# AdvESL_MeasureableSkills_IndividualsServed                                                                    float64
# AdvESL_MeasureableSkills_Participants12+Hours                                                                 float64
# AdvESL_MeasureableSkills_ParticipServed                                                                       float64
# AdvESL_MeasureableSkills_POPs                                                                                 float64
# AdvESL_MeasureableSkills_HSE                                                                                  float64
# AdvESL_MeasureableSkills_Postsecondary
# Enrollment                                                             float64
# AdvESL_MeasureableSkills_Post-test                                                                            float64
# AdvESL_MeasureableSkills_MSG                                                                                  float64
# Beg_ESL_Students                                                                                              float64
# LowBeg_ESL_Students                                                                                           float64
# LowBeg_ESL_PCTProgress                                                                                        float64
# HighBeg_ESL_Students                                                                                          float64
# HighBeg_ESL_PCTProgress                                                                                       float64
# LowInt_ESL_Students                                                                                           float64
# LowInt_ESL_PCTProgress                                                                                        float64
# HighInt_ESL_Students                                                                                          float64
# HighInt_ESL_PCTProgress                                                                                       float64
# Advanced_ESL_Students                                                                                         float64
# Advanced_ESL_PCTProgress                                                                                      float64
# Basic_Skills_Students
# (Denominator)                                                                           float64
# Basic_Skills_CompletingLevel
# LEVEL                                                                            float64
# Basic_Skills_PCTCompleting                                                                                    float64
# Beg_ABE_Lit_Students                                                                                          float64
# Beg_ABE_Lit_PCTProgress                                                                                       float64
# Beg_BasicEd_Students                                                                                          float64
# Beg_BasicEd_PCTProgress                                                                                       float64
# LowInt_BasicEd_Students                                                                                       float64
# LowInt_BasicEd_PCTProgress                                                                                    float64
# HighInt_BasicEd_Students                                                                                      float64
# HighInt_BasicEd_PCTProgress                                                                                   float64
# Low_AdultSecondary_Students                                                                                   float64
# Low_AdultSecondary_PCTProgress                                                                                float64
# BegABELit_Participant_POP_MSG                                                                                 float64
# BegABELit_IndividualsServed                                                                                   float64
# BegABELit_Participants12+ Hours                                                                               float64
# BegABELit_Particip/Served                                                                                     float64
# BegABELit_POPs                                                                                                float64
# BegABELit_HSE                                                                                                 float64
# BegABELit_Posttest                                                                                            float64
# BegABELit_MSG                                                                                                 float64
# BegBasicEd_Participant_POP_MSG                                                                                float64
# BegBasicEd_IndividualsServed                                                                                  float64
# BegBasicEd_Participants12+ Hours                                                                              float64
# BegBasicEd_Particip/Served                                                                                    float64
# BegBasicEd_POPs                                                                                               float64
# BegBasicEd_HSE                                                                                                float64
# BegBasicEd_Postsecondary                                                                                      float64
# BegBasicEd_Posttest                                                                                           float64
# BegBasicEd_MSG                                                                                                float64
# BegESLLit_Participant_POP_MSG                                                                                 float64
# BegESLLit_IndividualsServed                                                                                   float64
# BegESLLit_Participants12+ Hours                                                                               float64
# BegESLLit_Particip/Served                                                                                     float64
# BegESLLit_POPs                                                                                                float64
# BegESLLit_AHSGrad                                                                                             float64
# BegESLLit_HSE                                                                                                 float64
# BegESLLit_Postsecondary                                                                                       float64
# BegESLLit_AHSCredits                                                                                          float64
# BegESLLit_Posttest                                                                                            float64
# BegESLLit_MSG                                                                                                 float64
# Transfer30+Hours_Students                                                                                     float64
# Transfer30+Hours_PCTGreater2.25                                                                               float64
# TransferAssociateDeg_Students                                                                                 float64
# TransferAssociateDegree_PCTGreater2.25                                                                        float64
# Transfer_TotalStudents2016                                                                                    float64
# TransferTotal_NumberGreater2.252016                                                                           float64
# TransferTotal_PCTGreater2.252016                                                                              float64
# BASIC_SKILLS                                                                                                  float64
# NON_OCC_SS                                                                                                    float64
# OCC_RB                                                                                                        float64
# OCC_SS                                                                                                        float64
# Annual_ConEd_USnBdCupCount                                                                                    float64
# Annual Undup
# (Curr and ConEd)                                                                                 float64
# Unnamed: 1                                                                                                    float64
# 12 HOURS ATTEMPTED
# (Denominator)                                                                              float64
# 12 HOURS SUCCESSFUL
# (Numerator)                                                                               float64
# 16-17                                                                                                         float64
# 15-16                                                                                                         float64
# % SUCCESSFUL
# 14-15                                                                                            float64
# 13-14                                                                                                         float64
# 13-Dec                                                                                                        float64
# NumStudents1stYearSuccess_Age-15                                                                              float64
# PCT1stYearSuccess_Age-15                                                                                      float64
# NumStudents1stYearSuccess_Age16-17                                                                            float64
# PCT1stYearSuccess_Age16-17                                                                                    float64
# NumStudents1stYearSuccess_Age18                                                                               float64
# PCT1stYearSuccess_Age18                                                                                       float64
# NumStudents1stYearSuccess_Age19-24                                                                            float64
# PCT1stYearSuccess_Age19-24                                                                                    float64
# NumStudents1stYearSuccess_Age25-39                                                                            float64
# PCT1stYearSuccess_Age25-39                                                                                    float64
# NumStudents1stYearSuccess_Age40+                                                                              float64
# PCT1stYearSuccess_Age40+                                                                                      float64
# AAF_1stYearSuccessNumStudents                                                                                 float64
# AAF_1stYearSuccessPCT                                                                                         float64
# AAM_1stYearSuccessNumStudents                                                                                 float64
# AAM_1stYearSuccessPCT                                                                                         float64
# CF_1stYearSuccessNumStudents                                                                                  float64
# CF_1stYearSuccessPCT                                                                                          float64
# CM_1stYearSuccessNumStudents                                                                                  float64
# CM_1stYearSuccessPCT                                                                                          float64
# HF_1stYearSuccessNumStudents                                                                                  float64
# HF_1stYearSuccessPCT                                                                                          float64
# HM_1stYearSuccessNumStudents                                                                                  float64
# HM_1stYearSuccessPCT                                                                                          float64
# OF_1stYearSuccessNumStudents                                                                                  float64
# OF_1stYearSuccessPCT                                                                                          float64
# OM_1stYearSuccessNumStudents                                                                                  float64
# OM_1stYearSuccessPCT                                                                                          float64
# HighAdultSecEd_Participant_POP_MSG                                                                            float64
# HighAdultSecEd_IndividualsServed                                                                              float64
# HighAdultSecEd_Participants12+ Hours                                                                          float64
# HighAdultSecEd_Particip/Served                                                                                float64
# HighAdultSecEd_POPs                                                                                           float64
# HighAdultSecEd_AHSGrad                                                                                        float64
# HighAdultSecEd_HSE                                                                                            float64
# HighAdultSecEd_Postsecondary                                                                                  float64
# HighAdultSecEd_MSG                                                                                            float64
# HighBegESL_Participant_POP_MSG                                                                                float64
# HighBegESL_IndividualsServed                                                                                  float64
# HighBegESL_Participants12+ Hours                                                                              float64
# HighBegESL_Particip/Served                                                                                    float64
# HighBegESL_POPs                                                                                               float64
# HighBegESL_Posttest                                                                                           float64
# HighBegESL_MSG                                                                                                float64
# HighIntBasicEd_Participant_POP_MSG                                                                            float64
# HighIntBasicEd_IndividualsServed                                                                              float64
# HighIntBasicEd_Participants12+ Hours                                                                          float64
# HighIntBasicEd_Particip/Served                                                                                float64
# HighIntBasicEd_POPs                                                                                           float64
# HighIntBasicEd_AHSGrad                                                                                        float64
# HighIntBasicEd_HSE                                                                                            float64
# HighIntBasicEd_Postsecondary                                                                                  float64
# HighIntBasicEd_Posttest                                                                                       float64
# HighIntBasicEd_MSG                                                                                            float64
# HighInt_ESLMeasureableSkills_Participant_POP_MSG                                                              float64
# HighInt_ESLMeasureableSkills_IndividualsServed                                                                float64
# HighInt_ESLMeasureableSkills_Participants12+Hours                                                             float64
# HighInt_ESLMeasureableSkills_Particip/Served                                                                  float64
# HighInt_ESLMeasureableSkills_POPs                                                                             float64
# HighInt_ESLMeasureableSkills_Posttest                                                                         float64
# HighInt_ESLMeasureableSkills_MSG                                                                              float64
# Cosmetology_NumTest2017                                                                                       float64
# Cosmetology_PCTPassing2017                                                                                    float64
# Cosmetology_PCTPassing2016                                                                                    float64
# Cosmetology_PCTPassing2015                                                                                    float64
# Cosmetology_PCTPassing2014                                                                                    float64
# Blet_NumTest2017                                                                                              float64
# Blet_PCTPassing2017                                                                                           float64
# Blet_PCTPassing2016                                                                                           float64
# Blet_PCTPassing2015                                                                                           float64
# Blet_PCTPassing2014                                                                                           float64
# DetentionOfficer_NumTest2017                                                                                  float64
# DetentionOfficer_PCTPassing2017                                                                               float64
# DetentionOfficer_PCTPassing2016                                                                               float64
# EMTBasic_NumTest2017                                                                                          float64
# EMTBasic_PCTPassing2017                                                                                       float64
# EMTBasic_PCTPassing2016                                                                                       float64
# EMTBasic_PCTPassing2015                                                                                       float64
# EMTBasic_PCTPassing2014                                                                                       float64
# EMTParamedic_NumTest2017                                                                                      float64
# EMTParamedic_PCTPassing2017                                                                                   float64
# EMTParamedic_PCTPassing2015                                                                                   float64
# PracticalNursing_NumTest2017                                                                                  float64
# PracticalNursing_PCTPassing2017                                                                               float64
# PracticalNursing_PCTPassing2016                                                                               float64
# RegisteredNursing_NumTest2017                                                                                 float64
# RegisteredNursing_PCTPassing2017                                                                              float64
# RegisteredNursing_PCTPassing2016                                                                              float64
# RegisteredNursing_PCTPassing2015                                                                              float64
# RegisteredNursing_PCTPassing2014                                                                              float64
# LowAdultSecEd_Participant_POP_MSG                                                                             float64
# LowAdultSecEd_IndividualsServed                                                                               float64
# LowAdultSecEd_Participants12+ Hours                                                                           float64
# LowAdultSecEd_Particip/Served                                                                                 float64
# LowAdultSecEd_POPs                                                                                            float64
# LowAdultSecEd_AHSGrad                                                                                         float64
# LowAdultSecEd_HSE                                                                                             float64
# LowAdultSecEd_Postsecondary                                                                                   float64
# LowAdultSecEd_AHSCredits                                                                                      float64
# LowAdultSecEd_Posttest                                                                                        float64
# LowAdultSecEd_MSG                                                                                             float64
# LowBegESL_Participant_POP_MSG                                                                                 float64
# LowBegESL_IndividualsServed                                                                                   float64
# LowBegESL_Participants12+ Hours                                                                               float64
# LowBegESL_Particip/Served                                                                                     float64
# LowBegESL_POPs                                                                                                float64
# LowBegESL_AHSGrad                                                                                             float64
# LowBegESL_HSE                                                                                                 float64
# LowBegESL_Postsecondary                                                                                       float64
# LowBegESL_AHSCredits                                                                                          float64
# LowBegESL_Posttest                                                                                            float64
# LowBegESL_MSG                                                                                                 float64
# LowIntBasicEd_Participant_POP_MSG                                                                             float64
# LowIntBasicEd_IndividualsServed                                                                               float64
# LowIntBasicEd_Participants12+ Hours                                                                           float64
# LowIntBasicEd_Particip/Served                                                                                 float64
# LowIntBasicEd_POPs                                                                                            float64
# LowIntBasicEd_AHSGrad                                                                                         float64
# LowIntBasicEd_HSE                                                                                             float64
# LowIntBasicEd_Postsecondary                                                                                   float64
# LowIntBasicEd_Posttest                                                                                        float64
# LowIntBasicEd_MSG                                                                                             float64
# LowIntESL_Participant_POP_MSG                                                                                 float64
# LowIntESL_IndividualsServed                                                                                   float64
# LowIntESL_Participants
# (12+ Hours)                                                                            float64
# LowIntESL_Particip/Served                                                                                     float64
# LowIntESL_POPs                                                                                                float64
# LowIntESL_Posttest                                                                                            float64
# LowIntESL_MSG                                                                                                 float64
# Basic_Skills_Progress                                                                                         float64
# Credit_English_Success                                                                                        float64
# Credit_Math_Success                                                                                           float64
# First_Year_Progression                                                                                        float64
# Curr_Completion_Rate                                                                                          float64
# Licensure_Passing_Rate                                                                                        float64
# Transfer_Performance                                                                                          float64
# MEEL                                                                                                          float64
# ACABE                                                                                                         float64
# ABLBA                                                                                                         float64
# FALL_COHORT                                                                                                   float64
# CRED_ENG_ENROLLMENT                                                                                           float64
# CREDIT_ENG_SUCCESS                                                                                            float64
# ENG_PCT_Successful2015                                                                                        float64
# ENG_PCT_Successful2014                                                                                        float64
# ENG_PCT_Successful2013                                                                                        float64
# ENG_PCT_Successful2012                                                                                        float64
# FALL COHORT
# (Denominator)                                                                                     float64
# CRED MAT ENROLLMENT                                                                                           float64
# CREDIT MAT SUCCESS
# (Numerator)                                                                                float64
# 2015                                                                                                          float64
# % SUCCESSFUL
# 2014 2013                                                                                        float64
# Unnamed: 6                                                                                                    float64
# 2012                                                                                                          float64
# English_Students_Age-15                                                                                       float64
# English_SuccessPCT_Age-15                                                                                     float64
# English_Students_Age16-17                                                                                     float64
# English_SuccessPCT_Age16-17                                                                                   float64
# English_Students_Age18                                                                                        float64
# English_SuccessPCT_Age18                                                                                      float64
# English_Students_Age19-24                                                                                     float64
# English_SuccessPCT_Age19-24                                                                                   float64
# English_Students_Age25-39                                                                                     float64
# English_SuccessPCT_Age29-35                                                                                   float64
# English_Students_Age40+                                                                                       float64
# English_SuccessPCT_Age40+                                                                                     float64
# Math_Students_Age-15                                                                                          float64
# Math_SuccessPCT_Age-15                                                                                        float64
# Math_Students_Age16-17                                                                                        float64
# Math_SuccessPCT_Age16-17                                                                                      float64
# Math_Students_Age18                                                                                           float64
# Math_SuccessPCT_Age18                                                                                         float64
# Math_Students_Age19-24                                                                                        float64
# Math_SuccessPCT_Age19-24                                                                                      float64
# Math_Students_Age25-39                                                                                        float64
# Math_SuccessPCT_Age29-35                                                                                      float64
# Math_Students_Age40+                                                                                          float64
# Math_SuccessPCT_Age40+                                                                                        float64
# Associates_Total                                                                                              int64
# Associates_Men_Number                                                                                         int64
# Accosiates_Men_Percent                                                                                        float64
# Associates_Women_Number                                                                                       int64
# Associates_Women_Percent                                                                                      float64
# AwardLess1Year_Total                                                                                          float64
# AwardLess1Year_Men_Number                                                                                     float64
# AwardLess1Year_Men_Percent                                                                                    float64
# AwardLess1Year_Women_Number                                                                                   float64
# AwardLess1Year_Women_Percent                                                                                  float64
# AwardLess2Year_Total                                                                                          float64
# AwardLess2Year_Men_Number                                                                                     int64
# AwardLess2Year_Men_Percent                                                                                    float64
# AwardLess2Year_Women_Number                                                                                   int64
# AwardLess2Year_Women_Percent                                                                                  float64
# Certificate_Total                                                                                             int64
# Certificate_Men_Number                                                                                        int64
# Certificate_Men_Percent                                                                                       float64
# Certificate_Women_Number                                                                                      int64
# Full time Men                                                                                                 int64
# Full time Women                                                                                               int64
# Part time Men                                                                                                 int64
# Part time Total                                                                                               int64
# FirstTimeFullTimeUndergradsTotal                                                                              int64
# Financial_Aid_AnyAid                                                                                          int64
# Financial_Aid_FedGrants                                                                                       int64
# Financial_Aid_StateLocalGrants                                                                                int64
# StateLocalGrants_Avg                                                                                          int64
# Financial_Aid_InstitutionalGrants                                                                             int64
# InstitutionalGrants_Avg                                                                                       float64
# Financial_Aid_Loans                                                                                           int64
# Loans_Avg                                                                                                     int64
# Completers_150time_Grand total                                                                                int64
# Completers_150time_men                                                                                        int64
# Completers_150time_women                                                                                      int64
# Completers_150time_American Indian or Alaska Native                                                           int64
# Completers_150time_Asian                                                                                      int64
# Completers_150time_Black or African American                                                                  int64
# Completers_150time_Hispanic                                                                                   int64
# Completers_150time_White                                                                                      int64
# Completers_150time_Two or more races                                                                          int64
# Completers_150time_Race/ethnicity unknown                                                                     int64
# Grand total women                                                                                             int64
# American Indian or Alaska Native total                                                                        int64
# Asian total                                                                                                   int64
# Black or African American total                                                                               int64
# Hispanic total                                                                                                int64
# Native Hawaiian or Other Pacific Islander total                                                               int64
# White total                                                                                                   int64
# Two or more races total                                                                                       int64
# Race/ethnicity unknown total                                                                                  int64
# Nonresident alien total                                                                                       int64
# Full-time retention rate  2016                                                                                int64
# Part-time retention rate  2016                                                                                int64
# WhiteM_PCT086004                                                                                              float64
# WhiteM_PCT086017                                                                                              float64
# WhiteM_PCT086055                                                                                              float64
# WhiteM_PCT086090                                                                                              float64
# WhiteM_PCT086093                                                                                              float64
# AsianF_PCT086130                                                                                              float64
# AsianF_PCT086143                                                                                              float64
# AsianF_PCT086181                                                                                              float64
# AsianF_PCT086216                                                                                              float64
# AsianF_PCT086219                                                                                              float64
# AsianM_PCT086004                                                                                              float64
# AsianM_PCT086017                                                                                              float64
# AsianM_PCT086055                                                                                              float64
# AsianM_PCT086090                                                                                              float64
# AsianM_PCT086093                                                                                              float64
# BlackF_PCT086130                                                                                              float64
# BlackF_PCT086143                                                                                              float64
# BlackF_PCT086181                                                                                              float64
# BlackF_PCT086216                                                                                              float64
# BlackF_PCT086219                                                                                              float64
# BlackM_PCT086004                                                                                              float64
# BlackM_PCT086017                                                                                              float64
# BlackM_PCT086055                                                                                              float64
# BlackM_PCT086090                                                                                              float64
# BlackM_PCT086093                                                                                              float64
# HispanicF_PCT086130                                                                                           float64
# HispanicF_PCT086143                                                                                           float64
# HispanicF_PCT086181                                                                                           float64
# HispanicF_PCT086216                                                                                           float64
# HispanicF_PCT086219                                                                                           float64
# HispanicM_PCT086004                                                                                           float64
# HispanicM_PCT086017                                                                                           float64
# HispanicM_PCT086055                                                                                           float64
# HispanicM_PCT086090                                                                                           float64
# HispanicM_PCT086093                                                                                           float64
# IndianF_PCT086130                                                                                             float64
# IndianF_PCT086143                                                                                             float64
# IndianF_PCT086181                                                                                             float64
# IndianF_PCT086216                                                                                             float64
# IndianF_PCT086219                                                                                             float64
# IndianM_PCT086004                                                                                             float64
# IndianM_PCT086017                                                                                             float64
# IndianM_PCT086055                                                                                             float64
# IndianM_PCT086090                                                                                             float64
# IndianM_PCT086093                                                                                             float64
# OtherF_PCT086130                                                                                              float64
# OtherF_PCT086143                                                                                              float64
# OtherF_PCT086181                                                                                              float64
# OtherF_PCT086216                                                                                              float64
# OtherF_PCT086219                                                                                              float64
# OtherM_PCT086004                                                                                              float64
# OtherM_PCT086017                                                                                              float64
# OtherM_PCT086055                                                                                              float64
# OtherM_PCT086090                                                                                              float64
# OtherM_PCT086093                                                                                              float64
# TotalF_PCT086130                                                                                              float64
# TotalF_PCT086143                                                                                              float64
# TotalF_PCT086181                                                                                              float64
# TotalF_PCT086216                                                                                              float64
# TotalF_PCT086219                                                                                              float64
# TotalM_PCT086004                                                                                              float64
# TotalM_PCT086017                                                                                              float64
# TotalM_PCT086055                                                                                              float64
# TotalM_PCT086090                                                                                              float64
# TotalM_PCT086093                                                                                              float64
# TwoRaceF_PCT086130                                                                                            float64
# TwoRaceF_PCT086143                                                                                            float64
# TwoRaceF_PCT086181                                                                                            float64
# TwoRaceF_PCT086219                                                                                            float64
# TwoRaceM_PCT086004                                                                                            float64
# TwoRaceM_PCT086017                                                                                            float64
# TwoRaceM_PCT086055                                                                                            float64
# TwoRaceM_PCT086090                                                                                            float64
# TwoRaceM_PCT086093                                                                                            float64
# WhiteF_PCT086130                                                                                              float64
# WhiteF_PCT086143                                                                                              float64
# WhiteF_PCT086181                                                                                              float64
# WhiteF_PCT086216                                                                                              float64
# WhiteF_PCT086219                                                                                              float64
# Number of returns                                                                                             float64
# Number of single returns                                                                                      float64
# Number of joint returns                                                                                       float64
# Number of head of household returns                                                                           float64
# Number with paid preparer's signature                                                                         float64
# Number of exemptions                                                                                          float64
# Number of dependents                                                                                          float64
# Number of volunteer prepared returns [2]_Total                                                                float64
# Number of volunteer prepared returns [2]_Number of volunteer income tax assistance (VITA) prepared returns    float64
# Number of volunteer prepared returns [2]_Number of tax counseling for the elderly (TCE) prepared returns      float64
# Number of volunteer prepared returns [2]_Number of volunteer prepared
# returns with
# Earned Income Credit      float64
# Number of refund anticipation loan returns                                                                    float64
# Number of refund anticipation check returns                                                                   float64
# ...
# lea_sat_participation_pct                                                                                     float64
# ap_participation_pct                                                                                          float64
# lea_ap_participation_pct                                                                                      float64
# ap_pct_3_or_above                                                                                             float64
# lea_ap_pct_3_or_above                                                                                         float64
# total_specialized_courses                                                                                     float64
# ap_ib_courses                                                                                                 float64
# cte_courses                                                                                                   float64
# univ_college_courses                                                                                          float64
# lea_total_specialized_courses                                                                                 float64
# lea_ap_ib_courses                                                                                             float64
# lea_cte_courses                                                                                               float64
# lea_univ_college_courses                                                                                      float64
# st_total_specialized_courses                                                                                  float64
# st_ap_ib_courses                                                                                              float64
# st_cte_courses                                                                                                float64
# st_univ_college_courses                                                                                       float64
# ALL_All Students (Total or Subtotal_ENROLL_sch_pct                                                            float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct                                                              float64
# F_Female_ENROLL_sch_pct                                                                                       float64
# M_Male_ENROLL_sch_pct                                                                                         float64
# MB_Black_ENROLL_sch_pct                                                                                       float64
# MHL_Hispanic_ENROLL_sch_pct                                                                                   float64
# MW_White_ENROLL_sch_pct                                                                                       float64
# avg_daily_attend_pct                                                                                          float64
# crime_per_c_num                                                                                               float64
# short_susp_per_c_num                                                                                          float64
# long_susp_per_c_num                                                                                           float64
# stud_internet_comp_num                                                                                        float64
# lea_avg_daily_attend_pct                                                                                      float64
# lea_crime_per_c_num                                                                                           float64
# lea_short_susp_per_c_num                                                                                      float64
# lea_long_susp_per_c_num                                                                                       float64
# lea_stud_internet_comp_num                                                                                    float64
# st_avg_daily_attend_pct                                                                                       float64
# st_crime_per_c_num                                                                                            float64
# st_short_susp_per_c_num                                                                                       float64
# digital_media_pct                                                                                             float64
# avg_age_media_collection                                                                                      float64
# books_per_student                                                                                             float64
# lea_avg_age_media_collection                                                                                  int64
# lea_books_per_student                                                                                         float64
# wap_num                                                                                                       float64
# wap_per_classroom                                                                                             float64
# lea_wap_num                                                                                                   int64
# lea_wap_per_classroom                                                                                         float64
# flicensed_teach_pct                                                                                           float64
# tchyrs_0thru3_pct                                                                                             float64
# tchyrs_4thru10_pct                                                                                            float64
# tchyrs_11plus_pct                                                                                             float64
# class_teach_num                                                                                               float64
# nbpts_num                                                                                                     float64
# advance_dgr_pct                                                                                               float64
# _1yr_tchr_trnovr_pct                                                                                          float64
# emer_prov_teach_pct                                                                                           float64
# lateral_teach_pct                                                                                             float64
# highqual_class_pct                                                                                            float64
# lea_flicensed_teach_pct                                                                                       float64
# lea_tchyrs_0thru3_pct                                                                                         float64
# lea_tchyrs_4thru10_pct                                                                                        float64
# lea_tchyrs_11plus_pct                                                                                         float64
# lea_class_teach_num                                                                                           float64
# lea_nbpts_num                                                                                                 float64
# lea_advance_dgr_pct                                                                                           float64
# lea_1yr_tchr_trnovr_pct                                                                                       float64
# lea_emer_prov_teach_pct                                                                                       float64
# lea_lateral_teach_pct                                                                                         float64
# lea_highqual_class_hp_pct                                                                                     float64
# lea_highqual_class_lp_pct                                                                                     float64
# lea_highqual_class_all_pct                                                                                    float64
# lea_not_highqual_class_hp_pct                                                                                 float64
# lea_not_highqual_class_lp_pct                                                                                 float64
# lea_not_highqual_class_all_pct                                                                                float64
# st_flicensed_teach_pct                                                                                        float64
# st_tchyrs_0thru3_pct                                                                                          float64
# st_tchyrs_4thru10_pct                                                                                         float64
# st_nbpts_num                                                                                                  float64
# st_advance_dgr_pct                                                                                            float64
# st_1yr_tchr_trnovr_pct                                                                                        float64
# st_highqual_class_pct                                                                                         float64
# st_prin_white_pct                                                                                             float64
# 0-3 Years_Exp_Pct_Tch                                                                                         float64
# 10+ Years_Exp_Pct_Tch                                                                                         float64
# 4-10 Years_Exp_Pct_Tch                                                                                        float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                                                    float64
# 10+ Years_LEA_Exp_Pct_Prin                                                                                    float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                                                   float64
# Accomplished_TCHR_Standard 1_Pct                                                                              float64
# Accomplished_TCHR_Standard 2_Pct                                                                              float64
# Accomplished_TCHR_Standard 3_Pct                                                                              float64
# Accomplished_TCHR_Standard 4_Pct                                                                              float64
# Accomplished_TCHR_Standard 5_Pct                                                                              float64
# Developing_TCHR_Standard 1_Pct                                                                                float64
# Developing_TCHR_Standard 2_Pct                                                                                float64
# Developing_TCHR_Standard 3_Pct                                                                                float64
# Developing_TCHR_Standard 4_Pct                                                                                float64
# Developing_TCHR_Standard 5_Pct                                                                                float64
# Distinguished_TCHR_Standard 1_Pct                                                                             float64
# Distinguished_TCHR_Standard 2_Pct                                                                             float64
# Distinguished_TCHR_Standard 3_Pct                                                                             float64
# Distinguished_TCHR_Standard 4_Pct                                                                             float64
# Distinguished_TCHR_Standard 5_Pct                                                                             float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct                                                         float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct                                                               float64
# Meets Expected Growth_TCHR_Student Growth_Pct                                                                 float64
# Proficient_TCHR_Standard 1_Pct                                                                                float64
# Proficient_TCHR_Standard 2_Pct                                                                                float64
# Proficient_TCHR_Standard 3_Pct                                                                                float64
# Proficient_TCHR_Standard 4_Pct                                                                                float64
# Proficient_TCHR_Standard 5_Pct                                                                                float64
# AsianFemalePct                                                                                                float64
# AsianMalePct                                                                                                  float64
# AsianPct                                                                                                      float64
# BlackFemalePct                                                                                                float64
# BlackMalePct                                                                                                  float64
# BlackPct                                                                                                      float64
# HispanicFemalePct                                                                                             float64
# HispanicMalePct                                                                                               float64
# HispanicPct                                                                                                   float64
# IndianFemalePct                                                                                               float64
# IndianMalePct                                                                                                 float64
# IndianPct                                                                                                     float64
# MinorityMalePct                                                                                               float64
# PacificIslandFemalePct                                                                                        float64
# PacificIslandMalePct                                                                                          float64
# PacificIslandPct                                                                                              float64
# TwoOrMoreFemalePct                                                                                            float64
# TwoOrMoreMalePct                                                                                              float64
# TwoOrMorePct                                                                                                  float64
# SPG Grade_A                                                                                                   float64
# SPG Grade_B                                                                                                   float64
# SPG Grade_C                                                                                                   float64
# EVAAS Growth Status_Exceeded                                                                                  float64
# EVAAS Growth Status_Met                                                                                       float64
# EVAAS Growth Status_NotMet                                                                                    float64
# dtypes: float64(882), int64(45)
# memory usage: 427.4 KB
