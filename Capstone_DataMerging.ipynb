# %%
import dask.dataframe as dd
import os
import pandas as pd
import csv

# %%
files = os.listdir("/Users/lizzysterling/Desktop/Term4/Capstone/PostsecondaryAttainment/RawDatasets/")

# %%
files[1][-4:]
# Out:
# '.csv'

# %%
for i in range(len(files)):
    print files[i]
# Out:
# ACT_Scores.csv
# Admissions.csv
# Basic_Skills_ESL.csv
# Basic_Skills_Student_Progress.csv
# Basic_Skills_Student_Progress_Placement.csv
# Census_Datasets
# College_Transfer_Performance.csv
# Continuing_Education_Student_Enrollment.csv
# Curriculum_Completion.csv
# Curriculum_Completion_Age.csv
# Curriculum_Completion_Program.csv
# Curriculum_Completion_Program2.csv
# Curriculum_Completion_Race.csv
# Curriculum_Continuing_Education.csv
# Curriculum_Continuing_Education_Detail.csv
# Curriculum_Student_Enrollment.csv
# Data Scraping Code
# Degrees_byGender.csv
# Enrollment.csv
# Enrollment_byStudentLevel.csv
# FinancialAid.csv
# First_Year_Progression.csv
# First_Year_Progression_Age.csv
# First_Year_Progression_Race.csv
# License_Cert_Program1.csv
# License_Cert_Program2.csv
# License_Cert_Program3.csv
# License_Cert_Program4.csv
# License_Cert_Program5.csv
# Licensure_Cert_Passing.csv
# Measurable_Skill_Gains_Report.csv
# Performance_Measures_Report.csv
# Retention_NationalData.csv
# ...

# %%
csvFiles = []

for i in range(len(files)):
    if(files[i][-4:] == '.csv'):
        csvFiles.append(files[i])

# %%
counter = 0

for f in csvFiles:
    count = str(counter)
    if counter == 30:
        count = pd.read_csv(f, lineterminator='\n')
        counter += 1
    else:
        count = pd.read_csv(f)
        counter += 1

# %%
ACT_Scores = pd.read_csv(csvFiles[0])
Admissions = pd.read_csv(csvFiles[1])
Basic_Skills_ESL = pd.read_csv(csvFiles[2])
Basic_Skills_Student_Progress = pd.read_csv(csvFiles[3])
Basic_Skills_Student_Progress_Placement = pd.read_csv(csvFiles[4])
College_Transfer_Performance = pd.read_csv(csvFiles[5])
Continuing_Education_Student_Enrollment = pd.read_csv(csvFiles[6])
Curriculum_Completion = pd.read_csv(csvFiles[7])
Curriculum_Completion_Age = pd.read_csv(csvFiles[8])
Curriculum_Completion_Program = pd.read_csv(csvFiles[9])
Curriculum_Completion_Program2 = pd.read_csv(csvFiles[10])
Curriculum_Completion_Race = pd.read_csv(csvFiles[11])
Curriculum_Continuing_Education_Detail = pd.read_csv(csvFiles[12])
Curriculum_Continuing_Education = pd.read_csv(csvFiles[13])
Curriculum_Student_Enrollment = pd.read_csv(csvFiles[14])
Degrees_byGender = pd.read_csv(csvFiles[15])
Enrollment = pd.read_csv(csvFiles[16])
Enrollment_byStudentLevel = pd.read_csv(csvFiles[17])
FinancialAid = pd.read_csv(csvFiles[18])
First_Year_Progression = pd.read_csv(csvFiles[19])
First_Year_Progression_Age = pd.read_csv(csvFiles[20])
First_Year_Progression_Race = pd.read_csv(csvFiles[21])
License_Cert_Program1 = pd.read_csv(csvFiles[22])
License_Cert_Program2 = pd.read_csv(csvFiles[23])
License_Cert_Program3 = pd.read_csv(csvFiles[24])
License_Cert_Program4 = pd.read_csv(csvFiles[25])
License_Cert_Program5 = pd.read_csv(csvFiles[26])
Licensure_Cert_Passing = pd.read_csv(csvFiles[27])
Measurable_Skill_Gains_Report = pd.read_csv(csvFiles[28])
Performance_Measures_Report = pd.read_csv(csvFiles[29])
Retention_NationalData = pd.read_csv(csvFiles[30], lineterminator='\n')
SAT_Scores = pd.read_csv(csvFiles[31])
Student_Success_English = pd.read_csv(csvFiles[32])
Student_Success_Math = pd.read_csv(csvFiles[33])
Success_English = pd.read_csv(csvFiles[34])
Success_Math = pd.read_csv(csvFiles[35])

# %%
csvFiles[30] #checking proper assignment of certain variables
# Retention_NationalData needs some work
# Out:
# 'Retention_NationalData.csv'

# %% [markdown]
# ## ACT Scores

# %%
ACT_Scores = pd.read_csv("ACT_Scores.csv")

# %%
ACT_Scores.head()
# Out:
#   National Center for Education Statistics                    Unnamed: 1  \
# 0                 ACT test scores, 2016-17                           NaN
# 1                                   UnitId              Institution name
# 2                                      NaN                           NaN
# 3                                   199786    Alamance Community College
# 4                                   197869  Appalachian State University
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0              NaN              NaN              NaN              NaN
# 1    ACT Composite              NaN      ACT English              NaN
# 2  25th Percentile  75th Percentile  25th Percentile  75th Percentile
# 3                -                -                -                -
# 4               23               27               22               28
#
#         Unnamed: 6       Unnamed: 7                      Unnamed: 8  \
# ...

# %%
ACT_Scores = pd.DataFrame(ACT_Scores.iloc[:, 0:10])
ACT_Scores.columns = ["UnitID", "InstitutionName", "ACTComposite25", "ACTComposite75", "ACTEnglish25", "ACTEnglish75", "ACTMath25", "ACTMath75", "ACTNum", "ACTPerc"]
ACT_Scores = ACT_Scores.drop([0,1,2], axis = 0)

# %%
ACT_Scores.head()
# Out:
#    UnitID                                 InstitutionName ACTComposite25  \
# 3  199786                      Alamance Community College              -
# 4  197869                    Appalachian State University             23
# 5  197887  Asheville-Buncombe Technical Community College              -
# 6  197966               Beaufort County Community College              -
# 7  198011                        Bladen Community College              -
#
#   ACTComposite75 ACTEnglish25 ACTEnglish75 ACTMath25 ACTMath75 ACTNum ACTPerc
# 3              -            -            -         -         -      -       -
# 4             27           22           28        22        26   1751     56%
# 5              -            -            -         -         -      -       -
# 6              -            -            -         -         -      -       -
# 7              -            -            -         -         -      -       -

# %% [markdown]
# ## Admissions
# * Change all Technical Community College and Community College to TCC and CC respectively
#   * OR just match based on the first word of the column

# %%
Admissions = pd.read_csv("Admissions.csv")

# %%
Admissions.head()
# Out:
#   National Center for Education Statistics  \
# 0                      Admissions, 2016-17
# 1                                   UnitId
# 2                                   199786
# 3                                   197869
# 4                                   197887
#
#                                        Unnamed: 1            Unnamed: 2  \
# 0                                             NaN                   NaN
# 1                                Institution name  Number of applicants
# 2                      Alamance Community College                     -
# 3                    Appalachian State University                 13202
# 4  Asheville-Buncombe Technical Community College                     -
#
#         Unnamed: 3                    Unnamed: 4  \
# 0              NaN                           NaN
# 1  Number admitted  Number admitted who enrolled
# 2                -                             -
# 3             9020                          3125
# ...

# %%
Admissions = pd.DataFrame(Admissions.iloc[:, 0:7])
Admissions = Admissions.drop([0,1], axis = 0)
Admissions.columns = ["UnitID", "InstitutionName", "NumApplicants", "NumAdmited", "NumEnrolled", "PercentAdmitted", "PercentEnrolled"]

# %%
Admissions.head()
# Out:
#    UnitID                                 InstitutionName NumApplicants  \
# 2  199786                      Alamance Community College             -
# 3  197869                    Appalachian State University         13202
# 4  197887  Asheville-Buncombe Technical Community College             -
# 5  197966               Beaufort County Community College             -
# 6  198011                        Bladen Community College             -
#
#   NumAdmited NumEnrolled PercentAdmitted PercentEnrolled
# 2          -           -               -               -
# 3       9020        3125          68.30%          34.60%
# 4          -           -               -               -
# 5          -           -               -               -
# 6          -           -               -               -

# %% [markdown]
# ## Basic_Skills_ESL
#
# * System Totals

# %%
Basic_Skills_ESL = pd.read_csv("Basic_Skills_ESL.csv")

# %%
Basic_Skills_ESL.head()
# Out:
#              College Name BEGINNING ESL LOW BEGINNING ESL Unnamed: 3  \
# 0              weaknesses      Students          Progress   Students
# 1           System Totals          1145               71%       1403
# 2             Alamance CC            16               56%        178
# 3  Asheville-Buncombe TCC            13               85%         42
# 4      Beaufort County CC           NaN                 *          0
#
#   Unnamed: 4 HIGH BEGINNING ESL Unnamed: 6 LOW INTERMEDIATE ESL Unnamed: 8  \
# 0   Progress           Students   Progress             Students   Progress
# 1        77%               2001        75%                 2696        63%
# 2        46%                 74        76%                   36        69%
# 3        93%                 65        80%                   85        62%
# 4          *                  4          *                    4          *
#
#   HIGH INTERMEDIATE ESL Unnamed: 10 ADVANCED ESL Unnamed: 12
# ...

# %%
Basic_Skills_ESL.columns = ["InstitutionName", "BeginESLNum", "BeginESLProgress", "LowBeginESLNum", "LowBeginESLProgress", "HighBeginESLNum", "HighBeginESLProgress", "LowIntermediateESLNum", "LowIntermediateESLProgress", "HighIntermediateESLNum", "HighIntermediateESLProgress", "AdvancedESLNum", "AdvancedESLProgress"]
Basic_Skills_ESL = Basic_Skills_ESL.drop([0], axis = 0)

# %%
Basic_Skills_ESL.head()
# Out:
#           InstitutionName BeginESLNum BeginESLProgress LowBeginESLNum  \
# 1           System Totals        1145              71%           1403
# 2             Alamance CC          16              56%            178
# 3  Asheville-Buncombe TCC          13              85%             42
# 4      Beaufort County CC         NaN                *              0
# 5               Bladen CC           0                *              3
#
#   LowBeginESLProgress HighBeginESLNum HighBeginESLProgress  \
# 1                 77%            2001                  75%
# 2                 46%              74                  76%
# 3                 93%              65                  80%
# 4                   *               4                    *
# 5                   *               1                    *
#
#   LowIntermediateESLNum LowIntermediateESLProgress HighIntermediateESLNum  \
# 1                  2696                        63%                   2457
# ...

# %% [markdown]
# ## Basic_Skills_Student_Progress_Placement
# * Do I need to get rid of the SystemTotals column?

# %%
Basic_Skills_Student_Progress_Placement = pd.read_csv("Basic_Skills_Student_Progress_Placement.csv")

# %%
Basic_Skills_Student_Progress_Placement.head()
# Out:
#              College Name BEGINNING ABE LITERACY Unnamed: 2  \
# 0              weaknesses               Students   Progress
# 1           System Totals                   2301        33%
# 2             Alamance CC                     30        40%
# 3  Asheville-Buncombe TCC                    118         8%
# 4      Beaufort County CC                      5        20%
#
#   BEGINNING BASIC EDUCATION Unnamed: 4 LOW INTERMEDIATE BASIC EDUCATION  \
# 0                  Students   Progress                         Students
# 1                      3131        59%                             6600
# 2                        79        41%                              162
# 3                        33        45%                              108
# 4                        27        63%                               78
#
#   Unnamed: 6 HIGH INTERMEDIATE BASIC EDUCATION Unnamed: 8  \
# 0   Progress                          Students   Progress
# ...

# %%
Basic_Skills_Student_Progress_Placement.columns = ["InstitutionName", "BegAbeLitStudent", "BegAbeLitProgress", "BegBasicEdStudent", "BegBasicEdProgress", "LowIntBasicEdStudent", "LowIntBasicEdProgress", "HighIntBasicEdStudent", "HighIntBasicEdProgress", "LowSecondEdStudent", "LowSecondEdProgress"]
                                                                                                                               
Basic_Skills_Student_Progress_Placement = Basic_Skills_Student_Progress_Placement.drop([0], axis = 0)

# %%
Basic_Skills_Student_Progress_Placement.head()
# Out:
#           InstitutionName BegAbeLitStudent BegAbeLitProgress  \
# 1           System Totals             2301               33%
# 2             Alamance CC               30               40%
# 3  Asheville-Buncombe TCC              118                8%
# 4      Beaufort County CC                5               20%
# 5               Bladen CC               26               46%
#
#   BegBasicEdStudent BegBasicEdProgress LowIntBasicEdStudent  \
# 1              3131                59%                 6600
# 2                79                41%                  162
# 3                33                45%                  108
# 4                27                63%                   78
# 5                21                52%                   21
#
#   LowIntBasicEdProgress HighIntBasicEdStudent HighIntBasicEdProgress  \
# 1                   64%                  7017                    57%
# 2                   43%                   205                    49%
# ...

# %% [markdown]
# ## Basic_Skills_Student_Progress
# * System Totals? Should I make a new column for these that compares the school to the total completing level?

# %%
Basic_Skills_Student_Progress = pd.read_csv("Basic_Skills_Student_Progress.csv")

# %%
Basic_Skills_Student_Progress.head()
# Out:
#              College Name STUDENTS\r(Denominator) COMPLETING\rLEVEL   16-17  \
# 0           System Totals                  34,226            20,002  58.40%
# 1             Alamance CC                     969               483  49.80%
# 2  Asheville-Buncombe TCC                     799               446  55.80%
# 3      Beaufort County CC                     215               121  56.30%
# 4               Bladen CC                     150                94  62.70%
#
#   15-16 % COMPLETING\r14-15 13-14 13-Dec
# 0   58%                 56%   58%    58%
# 1   49%                 46%   44%    35%
# 2   56%                 54%   61%    54%
# 3   45%                 51%   52%    50%
# 4   69%                 62%   63%    57%

# %%
Basic_Skills_Student_Progress.columns = ["InstitutionName", "Students", "CompleteLevel", "Perc16/17", "Perc15/16", "Perc14/15", "Perc13/14", "Perc12/13"]

# %%
Basic_Skills_Student_Progress.head()
# Out:
#           InstitutionName Students CompleteLevel Perc16/17 Perc15/16  \
# 0           System Totals   34,226        20,002    58.40%       58%
# 1             Alamance CC      969           483    49.80%       49%
# 2  Asheville-Buncombe TCC      799           446    55.80%       56%
# 3      Beaufort County CC      215           121    56.30%       45%
# 4               Bladen CC      150            94    62.70%       69%
#
#   Perc14/15 Perc13/14 Perc12/13
# 0       56%       58%       58%
# 1       46%       44%       35%
# 2       54%       61%       54%
# 3       51%       52%       50%
# 4       62%       63%       57%

# %% [markdown]
# ## College_Transfer_Performance
# * Change to InstitutionName
# * What are these variables saying?

# %%
College_Transfer_Performance = pd.read_csv("College_Transfer_Performance.csv")

# %%
College_Transfer_Performance.head()
# Out:
#              College Name Students % ___ 2.25 Students.1 % ___ 2.25.1  \
# 0           System Totals    5,220        79%      6,397          87%
# 1             Alamance CC       87        80%        121          81%
# 2  Asheville-Buncombe TCC      141        88%        243          93%
# 3      Beaufort County CC       28        86%         59          92%
# 4               Bladen CC       35        86%         26          81%
#
#   Students\r(Denominator) # ___ 2.25 % ___ 2.25.2 14-15 13-14 13-Dec 12-Nov  \
# 0                  11,617      9,694       83.40%   83%   82%    82%    82%
# 1                     208        168       80.80%   86%   83%    83%    80%
# 2                     384        349       90.90%   91%   89%    87%    90%
# 3                      87         78       89.70%   81%   82%    78%    85%
# 4                      61         51       83.60%   71%   66%    60%    70%
#
#   11-Oct
# 0    81%
# 1    79%
# 2    92%
# 3    89%
# 4    67%

# %% [markdown]
# ## Continuing_Education_Student_Enrollment
# * Look into these variable meanings

# %%
Continuing_Education_Student_Enrollment = pd.read_csv("Continuing_Education_Student_Enrollment.csv")

# %%
Continuing_Education_Student_Enrollment.head()
# Out:
#              College Name BASIC\nSKILLS COMM\nSVC  FIT    HRD  LEARN\nLAB  \
# 0             Alamance CC         1,899       NaN  NaN    NaN         NaN
# 1  Asheville-Buncombe TCC         2,000       NaN  NaN  183.0         NaN
# 2      Beaufort County CC           622       NaN  NaN   56.0         NaN
# 3               Bladen CC           362       NaN  NaN  175.0         NaN
# 4           Blue Ridge CC         1,013       NaN  NaN    NaN         NaN
#
#   NON\nOCC SS OCC RB OCC SS Annual ConEd\nUSnBdCupCount Unnamed: 10  \
# 0         729  4,150  2,355                    20 8,801      14,275
# 1       2,766  6,405  2,420                   16 13,340      22,679
# 2         794  2,806    310                       4,455       6,344
# 3         660  1,581    115                       2,815       4,258
# 4       2,147  5,194    879                       8,719      11,198
#
#   Annual Undup\n(Curr and ConEd)
# 0                            NaN
# 1                            NaN
# ...

# %%
Continuing_Education_Student_Enrollment.columns = ["InstitutionName", "BasicSkills", "CommSVC", "FIT", "HRD", "LearnLAB", "NonOC_CSS", "OCC_RB", "OCC_SS", "AnnualUSnBdCupCount", "?", "AnnualUndup"]

# %%
Continuing_Education_Student_Enrollment.head()
# Out:
#           InstitutionName BasicSkills CommSVC  FIT    HRD  LearnLAB NonOC_CSS  \
# 0             Alamance CC       1,899     NaN  NaN    NaN       NaN       729
# 1  Asheville-Buncombe TCC       2,000     NaN  NaN  183.0       NaN     2,766
# 2      Beaufort County CC         622     NaN  NaN   56.0       NaN       794
# 3               Bladen CC         362     NaN  NaN  175.0       NaN       660
# 4           Blue Ridge CC       1,013     NaN  NaN    NaN       NaN     2,147
#
#   OCC_RB OCC_SS AnnualUSnBdCupCount       ? AnnualUndup
# 0  4,150  2,355            20 8,801  14,275         NaN
# 1  6,405  2,420           16 13,340  22,679         NaN
# 2  2,806    310               4,455   6,344         NaN
# 3  1,581    115               2,815   4,258         NaN
# 4  5,194    879               8,719  11,198         NaN

# %% [markdown]
# ## Curriculum_Completion
# * System Totals

# %%
Curriculum_Completion = pd.read_csv("Curriculum_Completion.csv")

# %%
Curriculum_Completion.head()
# Out:
#                  College Name % CC GRADUATE AND UNIV TRANSFER Unnamed: 2  \
# 0                         NaN                             NaN       2011
# 1               System Totals                          46,578         9%
# 2                 Alamance CC                            1080         5%
# 3  Asheville-Buncombe TCC1308                             NaN        10%
# 4          Beaufort County CC                             386         4%
#
#   Unnamed: 3 Unnamed: 4 % CC GRADUATE, NOT UNIV TRANSFER Unnamed: 6  \
# 0       2010       2009                             2008       2011
# 1         8%         7%                               7%        13%
# 2         3%         4%                               6%        13%
# 3         9%         6%                               7%        16%
# 4         5%         4%                               6%        10%
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      \
# 0       2010       2009       2008     ...
# ...

# %%
Curriculum_Completion.columns = ["InstitutionName", "Students", "GradTrans2011", "GradTrans2010", "GradTrans2009", "GradTrans2008", "GradNoTrans2011", "GradNoTrans2010", "GradNoTrans2009", "GradNoTrans2008", "NoGradTrans2011", "NoGradTrans2010", "NoGradTrans2009","NoGradTrans2008", "NoGradNoTrans2011", "NoGradNoTrans2010", "NoGradNoTrans2009", "NoGradNoTrans2008", "StudentTrans", "GradTrans2011", "GradTrans2010", "GradTrans2009", "GRadTrans2008"]
Curriculum_Completion = Curriculum_Completion.drop([0], axis = 0)

# %%
Curriculum_Completion.head()
# Out:
#               InstitutionName Students GradTrans2011 GradTrans2010  \
# 1               System Totals   46,578            9%            8%
# 2                 Alamance CC     1080            5%            3%
# 3  Asheville-Buncombe TCC1308      NaN           10%            9%
# 4          Beaufort County CC      386            4%            5%
# 5                   Bladen CC      210            4%            2%
#
#   GradTrans2009 GradTrans2008 GradNoTrans2011 GradNoTrans2010 GradNoTrans2009  \
# 1            7%            7%             13%             14%             14%
# 2            4%            6%             13%             10%             11%
# 3            6%            7%             16%             11%             14%
# 4            4%            6%             10%             13%             13%
# 5            4%            6%              8%              8%             11%
#
#   GradNoTrans2008      ...      NoGradTrans2008 NoGradNoTrans2011  \
# ...

# %% [markdown]
# ## Curriculum_Completion_Age
# * System Totals

# %%
Curriculum_Completion_Age = pd.read_csv("Curriculum_Completion_Age.csv")

# %%
Curriculum_Completion_Age.head()
# Out:
#                   Unnamed: 0   -15 Unnamed: 2 16-17 Unnamed: 4     18  \
# 0               College Name     #          %     #          %      #
# 1              System Totals  3674        62%  9537        54%  14326
# 2                Alamance CC    40        48%   422        50%    284
# 3  Asheville-Buncombe TCC127   NaN        57%   482        55%    278
# 4         Beaufort County CC    53        47%    91        45%     94
#
#   Unnamed: 6  19-24 Unnamed: 8 25-39     ...     16-17.1 Unnamed: 16 18.1  \
# 0          %      #          %     #     ...         '10         '09  '10
# 1        44%  11265        34%  4798     ...         54%         54%  43%
# 2        47%    188        34%    81     ...         55%         49%  35%
# 3        41%    200        36%   141     ...         53%         50%  42%
# 4        38%     83        28%    39     ...         36%         48%  39%
#
#   Unnamed: 18 19-24.1 Unnamed: 20 25-39.1 Unnamed: 22 40+.1 Unnamed: 24
# ...

# %%
Curriculum_Completion_Age.columns = ["InstitutionName","CC<=15Num", "CC<=15Perc", "CC16-17Num", "CC16-17Perc", "CC18Num", "CC18Perc", "CC19-24Num", "CC19-24Perc", "CC25-39Num", "CC25-39Perc", "CC40+Num", "CC40+Perc","CC2010<=15Perc", "CC2009<=15Perc", "CC201016-17Perc", "CC200916-17Perc", "CC201018Perc", "CC200918Perc", "CC201019-24Perc", "CC200919-24Perc", "CC201025-39Perc", "CC200925-39Perc", "CC201040+Perc", "CC200940+Perc"]
Curriculum_Completion_Age = Curriculum_Completion_Age.drop([0], axis = 0)

# %%
Curriculum_Completion_Age.head()
# Out:
#              InstitutionName CC<=15Num CC<=15Perc CC16-17Num CC16-17Perc  \
# 1              System Totals      3674        62%       9537         54%
# 2                Alamance CC        40        48%        422         50%
# 3  Asheville-Buncombe TCC127       NaN        57%        482         55%
# 4         Beaufort County CC        53        47%         91         45%
# 5                  Bladen CC         1          *         45         36%
#
#   CC18Num CC18Perc CC19-24Num CC19-24Perc CC25-39Num      ...       \
# 1   14326      44%      11265         34%       4798      ...
# 2     284      47%        188         34%         81      ...
# 3     278      41%        200         36%        141      ...
# 4      94      38%         83         28%         39      ...
# 5      56      36%         66         26%         30      ...
#
#   CC201016-17Perc CC200916-17Perc CC201018Perc CC200918Perc CC201019-24Perc  \
# ...

# %% [markdown]
# ## Curriculum_Completion_Program
# * SystemTotals

# %%
Curriculum_Completion_Program = pd.read_csv("Curriculum_Completion_Program.csv")

# %%
Curriculum_Completion_Program.head()
# Out:
#                Unnamed: 0 AGRICULTURAL AND NATURAL RES TECH Unnamed: 2  \
# 0            College Name                          Students    Success
# 1           System Totals                               361        40%
# 2             Alamance CC                                15        33%
# 3  Asheville-Buncombe TCC                                 3          *
# 4      Beaufort County CC                                 2          *
#
#   ARTS AND SCIENCES Unnamed: 4 BIOLOGICAL AND CHEMICAL TECH Unnamed: 6  \
# 0          Students    Success                     Students    Success
# 1            21,636        46%                           95        34%
# 2               330        47%                            4          *
# 3               415        55%                            2          *
# 4               174        40%                            0          *
#
#   BUSINESS TECHNOLOGIES Unnamed: 8 COMMERCIAL AND ARTISTIC PROD TECH  \
# ...

# %%
Curriculum_Completion_Program.columns = ["InstitutionName", "Agricultural&NaturalResTechNum", "Agricultural&NaturalResTechSuccess", "Arts&SciencesNum", "Arts&SciencesSuccess", "Bio&ChemTechNum", "BioChemTechSuccess", "BizTechNum", "BizTechSuccess", "Commercial&ArtProdTechNum", "Commercial&ArtProdTechSuccess", "ConstructionTechNum", "ConstructionTechSuccess"]
Curriculum_Completion_Program = Curriculum_Completion_Program.drop([0], axis = 0)

# %%
Curriculum_Completion_Program.head()
# Out:
#           InstitutionName Agricultural&NaturalResTechNum  \
# 1           System Totals                            361
# 2             Alamance CC                             15
# 3  Asheville-Buncombe TCC                              3
# 4      Beaufort County CC                              2
# 5               Bladen CC                              1
#
#   Agricultural&NaturalResTechSuccess Arts&SciencesNum Arts&SciencesSuccess  \
# 1                                40%           21,636                  46%
# 2                                33%              330                  47%
# 3                                  *              415                  55%
# 4                                  *              174                  40%
# 5                                  *               94                  33%
#
#   Bio&ChemTechNum BioChemTechSuccess BizTechNum BizTechSuccess  \
# 1              95                34%      6,206            39%
# ...

# %% [markdown]
# ## Curriculum_Completion_Program2
# * SystemTotals
# * Merge with CCP1

# %%
Curriculum_Completion_Program2 = pd.read_csv("Curriculum_Completion_Program2.csv")

# %%
Curriculum_Completion_Program2.head()
# Out:
#                Unnamed: 0 ENGINEERING TECHNOLOGIES Unnamed: 2 HEALTH SCIENCES  \
# 0            College Name                 Students    Success        Students
# 1           System Totals                      951        39%           3,153
# 2             Alamance CC                        2          *              35
# 3  Asheville-Buncombe TCC                       51        39%             101
# 4      Beaufort County CC                       15        13%              28
#
#   Unnamed: 4 INDUSTRIAL TECHNOLOGIES Unnamed: 6 PUBLIC SERVICE TECHNOLOGIES  \
# 0    Success                Students    Success                    Students
# 1        54%                   1,315        34%                       6,514
# 2        66%                      34        26%                         138
# 3        66%                      23        30%                         280
# 4        64%                      24        17%                          51
#
# ...

# %%
Curriculum_Completion_Program2.columns = ["InstitutionName", "EngineTechNum", "EngineTechSuccess", "HealthScienceNum", "HealthScienceSuccess", "IndustrialTechNum", "IndustrialTechSuccess", "PublicServiceTechNum", "PublicServiceTechSuccess", "TransportSystemsTechNum", "TransportSystemsTechSuccess", "SpecialCatNum", "SpecialCatSuccess"]
Curriculum_Completion_Program2 = Curriculum_Completion_Program2.drop([0], axis = 0)

# %%
Curriculum_Completion_Program2.head()
# Out:
#           InstitutionName EngineTechNum EngineTechSuccess HealthScienceNum  \
# 1           System Totals           951               39%            3,153
# 2             Alamance CC             2                 *               35
# 3  Asheville-Buncombe TCC            51               39%              101
# 4      Beaufort County CC            15               13%               28
# 5               Bladen CC             0                 *               13
#
#   HealthScienceSuccess IndustrialTechNum IndustrialTechSuccess  \
# 1                  54%             1,315                   34%
# 2                  66%                34                   26%
# 3                  66%                23                   30%
# 4                  64%                24                   17%
# 5                  54%                19                   11%
#
#   PublicServiceTechNum PublicServiceTechSuccess TransportSystemsTechNum  \
# ...

# %% [markdown]
# ## Curriculum_Completion_Race
# * SystemTotals

# %%
Curriculum_Completion_Race = pd.read_csv("Curriculum_Completion_Race.csv")

# %%
Curriculum_Completion_Race.head()
# Out:
#                Unnamed: 0 AFRICAN-AMER FEMALE Unnamed: 2 AFRICAN-AMERIC MALE  \
# 0            College Name            Students    Success            Students
# 1           System Totals               6,436        41%               5,098
# 2             Alamance CC                 128        45%                  92
# 3  Asheville-Buncombe TCC                  46        41%                  48
# 4      Beaufort County CC                  76        37%                  56
#
#   Unnamed: 4 CAUCASIAN FEMALE Unnamed: 6 CAUCASIAN MALE Unnamed: 8  \
# 0    Success         Students    Success       Students    Success
# 1        31%           13,978        49%         12,457        44%
# 2        33%              335        48%            312        46%
# 3        38%              527        51%            504        44%
# 4        21%              113        42%            104        32%
#
#   HISPANIC FEMALE Unnamed: 10 HISPANIC MALE Unnamed: 12 OTHER FEMALE  \
# ...

# %%
Curriculum_Completion_Race.columns = ["InstitutionName", "AfricanAmericanFemaleNum", "AfricanAmericanFemaleSuccess", "AfricanAmericanMaleNum", "AfricanAmericanMaleSuccess", "CaucFemaleNum", "CaucFemaleSuccess", "CaucMaleNum", "CaucMaleSuccess", "HispFemaleNum", "HispFemaleSuccess", "HispMaleNum", "HispMaleSuccess", "OtherFemaleNum", "OtherFemaleSuccess", "OtherMaleNum", "OtherMaleSuccess"]
Curriculum_Completion_Race = Curriculum_Completion_Race.drop([0], axis = 0)

# %%
Curriculum_Completion_Race.head()
# Out:
#           InstitutionName AfricanAmericanFemaleNum  \
# 1           System Totals                    6,436
# 2             Alamance CC                      128
# 3  Asheville-Buncombe TCC                       46
# 4      Beaufort County CC                       76
# 5               Bladen CC                       62
#
#   AfricanAmericanFemaleSuccess AfricanAmericanMaleNum  \
# 1                          41%                  5,098
# 2                          45%                     92
# 3                          41%                     48
# 4                          37%                     56
# 5                          27%                     30
#
#   AfricanAmericanMaleSuccess CaucFemaleNum CaucFemaleSuccess CaucMaleNum  \
# 1                        31%        13,978               49%      12,457
# 2                        33%           335               48%         312
# 3                        38%           527               51%         504
# ...

# %% [markdown]
# ## Curriculum_Continuing_Education_Detail
# * Look into variablel meanings

# %%
Curriculum_Continuing_Education_Detail = pd.read_csv("Curriculum_Continuing_Education_Detail.csv")

# %%
Curriculum_Continuing_Education_Detail.head()
# Out:
#               Unnamed: 0 Unnamed: 1 Curriculum Programs  \
# 0               Colleges  Associate         Certificate
# 1            Alamance CC   2,889.60               277.3
# 2  Asheville-Buncombe TC   4,706.40               398.6
# 3     Beaufort County CC   1,002.40                24.3
# 4              Bladen CC      857.6                66.2
#
#                  Unnamed: 3 Unnamed: 4    Unnamed: 5             Unnamed: 6  \
# 0  College Transfer Pathway    Diploma  Transitional  Total Curr Actual FTE
# 1                     178.9      101.2          84.8        A3l,a5m3a1n.c8e
# 2                      75.6      174.6         439.7      A5s,h7e9v4il.l9e-
# 3                      69.4       42.2          25.3        B1e,a1u6f3o.r6t
# 4                       101       59.7          29.8         B1l,a1d1e4n.3C
#
#      Unnamed: 7 Unnamed: 8  Continuing Education Programs  \
# 0  Basic Skills     Occ Rb  Subtotal CE Actual Budget FTE
# ...

# %%
Curriculum_Continuing_Education_Detail.columns = ["InstitutionName", "Associate", "Certificate", "CollegeTransferPathway", "Diploma", "Transitional", "TotalCurrActualFTE", "BasicSkills", "OccRb", "SubTotCEActualBudgetFTE", "SelfSupportedOccupationalExtension", "SmBizCenterSbc", "CommunityServSupported&ReceiptSupport", "SelfSupportedNonOccupational", "CustomTraining", "SubTotCENonBudgetFTE", "TOTAL"]
Curriculum_Continuing_Education_Detail = Curriculum_Continuing_Education_Detail.drop([0], axis = 0)

# %%
Curriculum_Continuing_Education_Detail.head()
# Out:
#          InstitutionName Associate Certificate CollegeTransferPathway Diploma  \
# 1            Alamance CC  2,889.60       277.3                  178.9   101.2
# 2  Asheville-Buncombe TC  4,706.40       398.6                   75.6   174.6
# 3     Beaufort County CC  1,002.40        24.3                   69.4    42.2
# 4              Bladen CC     857.6        66.2                    101    59.7
# 5          Blue Ridge CC  1,361.10       132.9                   37.8   128.4
#
#   Transitional TotalCurrActualFTE BasicSkills  OccRb SubTotCEActualBudgetFTE  \
# 1         84.8    A3l,a5m3a1n.c8e       329.9  340.6              Ala67m0.a5
# 2        439.7  A5s,h7e9v4il.l9e-       363.3  504.1             As8h6e7.v4i
# 3         25.3    B1e,a1u6f3o.r6t          98    235               Bea3u3f3o
# 4         29.8     B1l,a1d1e4n.3C        56.3  174.2             Bla23d0e.n5
# 5         50.7    B1l,u7e1R0i.d9g        81.4  336.7             Blu41e8.R1i
#
# ...

# %% [markdown]
# ## Curriculum_Continuing_Education
# * Variable meanings

# %%
Curriculum_Continuing_Education = pd.read_csv("Curriculum_Continuing_Education.csv")

# %%
Curriculum_Continuing_Education.head()
# Out:
#                Unnamed: 0      Curriculum Programs   Unnamed: 2  \
# 0            College Name  Curr Actual Budget FTE*  Curr SS FTE
# 1             Alamance CC                 3,531.80          NaN
# 2  Asheville-Buncombe TCC                 5,794.90          NaN
# 3      Beaufort County CC                 1,163.60          NaN
# 4               Bladen CC                 1,114.30          NaN
#
#              Unnamed: 3             Basic Skills  \
# 0  Total Curriculum FTE  Basic Skills Budget FTE
# 1              3,531.80                    329.9
# 2              5,794.90                    363.3
# 3              1,163.60                       98
# 4              1,114.30                     56.3
#
#                       Unnamed: 5          Unnamed: 6 Continuing Education  \
# 0  Total Basic Skills Budget FTE  OCC Reg Budget FTE            CC SS FTE
# 1                          329.9               340.6                 15.9
# ...

# %%
Curriculum_Continuing_Education.columns = ["InstitutionName", "CurrActualBudgetFTE", "CurrSSFTE", "TotalCurrFTE", "BasicSkillsBudgetFTE", "TotalBasicSkillsBudgetFTE", "OCCRegBudgetFTE", "CCSSFTE", "CECatFundedFTE", "TotalConEdFTE", "TotalBudgetFTE", "TotalSelfSupportFTE", "TotalCECatFundedFTE", "TotalFTEbyCollege"]
Curriculum_Continuing_Education = Curriculum_Continuing_Education.drop([0], axis = 0)

# %%
Curriculum_Continuing_Education.head()
# Out:
#           InstitutionName CurrActualBudgetFTE CurrSSFTE TotalCurrFTE  \
# 1             Alamance CC            3,531.80       NaN     3,531.80
# 2  Asheville-Buncombe TCC            5,794.90       NaN     5,794.90
# 3      Beaufort County CC            1,163.60       NaN     1,163.60
# 4               Bladen CC            1,114.30       NaN     1,114.30
# 5           Blue Ridge CC            1,710.90       NaN     1,710.90
#
#   BasicSkillsBudgetFTE TotalBasicSkillsBudgetFTE OCCRegBudgetFTE CCSSFTE  \
# 1                329.9                     329.9           340.6    15.9
# 2                363.3                     363.3           504.1   142.2
# 3                   98                        98             235    12.9
# 4                 56.3                      56.3           174.2     6.6
# 5                 81.4                      81.4           336.7      52
#
#   CECatFundedFTE TotalConEdFTE TotalBudgetFTE TotalSelfSupportFTE  \
# ...

# %% [markdown]
# ## Curriculum_Student_Enrollment

# %%
Curriculum_Student_Enrollment = pd.read_csv("Curriculum_Student_Enrollment.csv")

# %%
Curriculum_Student_Enrollment.head()
# Out:
#              College Name Transfer/General Eduction  \
# 0             Alamance CC                     2,910
# 1  Asheville-Buncombe TCC                     3,708
# 2      Beaufort County CC                     1,228
# 3               Bladen CC                       911
# 4           Blue Ridge CC                     1,158
#
#   Career/Technical Education Special Credit Annual Curr Undup Count  \
# 0                      2,883            333                   5,877
# 1                      5,015          1,515                   9,911
# 2                        707            125                   2,005
# 3                        637            109                   1,614
# 4                      1,564            226                   2,868
#
#   Annual Undup Student Count (Curr and ConEd)
# 0                                      14,275
# 1                                      22,679
# 2                                       6,344
# 3                                       4,258
# ...

# %%
Curriculum_Student_Enrollment.columns = ["InstitutionName", "Transfer/GeneralEd", "Career/TechEd", "SpecialCredit", "AnnualCurrUndupCount", "AnnualUndupStudentCount"]

# %%
Curriculum_Student_Enrollment.head()
# Out:
#           InstitutionName Transfer/GeneralEd Career/TechEd SpecialCredit  \
# 0             Alamance CC              2,910         2,883           333
# 1  Asheville-Buncombe TCC              3,708         5,015         1,515
# 2      Beaufort County CC              1,228           707           125
# 3               Bladen CC                911           637           109
# 4           Blue Ridge CC              1,158         1,564           226
#
#   AnnualCurrUndupCount AnnualUndupStudentCount
# 0                5,877                  14,275
# 1                9,911                  22,679
# 2                2,005                   6,344
# 3                1,614                   4,258
# 4                2,868                  11,198

# %% [markdown]
# ## Degrees_byGender

# %%
Degrees_byGender = pd.read_csv("Degrees_byGender.csv")

# %%
Degrees_byGender.head()
# Out:
#             National Center for Education Statistics  \
# 0  Degrees/certificates by gender 2015-16 - Acade...
# 1                                             UnitId
# 2                                             199786
# 3                                             199786
# 4                                             199786
#
#                    Unnamed: 1                          Unnamed: 2 Unnamed: 3  \
# 0                         NaN                                 NaN        NaN
# 1           Institution name                                Level      Total
# 2  Alamance Community College                  Associate's degree        493
# 3  Alamance Community College                                   -          -
# 4  Alamance Community College  Award of less than 1 academic year        386
#
#    Unnamed: 4   Unnamed: 5    Unnamed: 6     Unnamed: 7
# 0         NaN          NaN           NaN            NaN
# 1  Men Number  Men Percent  Women Number  Women Percent
# ...

# %%
Degrees_byGender.columns = ["UnitID", "InstitutionName", "Level", "Total", "MenNum", "MenPerc", "WomenNum", "WomenPerc"]
Degrees_byGender = Degrees_byGender.drop([0,1], axis = 0)

# %%
Degrees_byGender.head()
# Out:
#    UnitID             InstitutionName  \
# 2  199786  Alamance Community College
# 3  199786  Alamance Community College
# 4  199786  Alamance Community College
# 5  199786  Alamance Community College
# 6  199786  Alamance Community College
#
#                                                Level Total MenNum MenPerc  \
# 2                                 Associate's degree   493    162    32.9
# 3                                                  -     -      -       0
# 4                 Award of less than 1 academic year   386    208    53.9
# 5  Award of at least 1 but less than 2 academic y...    67     24    35.8
# 6                                                  -     -      -       0
#
#   WomenNum WomenPerc
# 2      331      67.1
# 3        -         0
# 4      178      46.1
# 5       43      64.2
# 6        -         0

# %% [markdown]
# ## Enrollment

# %%
Enrollment = pd.read_csv("Enrollment.csv")

# %%
Enrollment.head()
# Out:
#   National Center for Education Statistics                        Unnamed: 1  \
# 0                         Total enrollment                    selected years
# 1                                   UnitId                  Institution Name
# 2                                   197814          College of the Albemarle
# 3                                   197850  South Piedmont Community College
# 4                                   197869      Appalachian State University
#
#   Unnamed: 2 Unnamed: 3
# 0        NaN        NaN
# 1  Fall 2015  Fall 2016
# 2       2141       2268
# 3       2608       2751
# 4      17932      18295

# %%
Enrollment.columns = ["UnitID", "InstitutionName", "Fall2015", "Fall2016"]
Enrollment = Enrollment.drop([0,1], axis = 0)

# %%
Enrollment.head()
# Out:
#    UnitID                                 InstitutionName Fall2015 Fall2016
# 2  197814                        College of the Albemarle     2141     2268
# 3  197850                South Piedmont Community College     2608     2751
# 4  197869                    Appalachian State University    17932    18295
# 5  197887  Asheville-Buncombe Technical Community College     7233     7226
# 6  197966               Beaufort County Community College     1820     1522

# %% [markdown]
# ## Enrollment_byStudentLevel

# %%
Enrollment_byStudentLevel = pd.read_csv("Enrollment_byStudentLevel.csv")

# %%
Enrollment_byStudentLevel.head()
# Out:
#   National Center for Education Statistics                  Unnamed: 1  \
# 0    Enrollment by student level Fall 2016                         NaN
# 1                                   UnitId            Institution name
# 2                                   199786  Alamance Community College
# 3                                   199786  Alamance Community College
# 4                                   199786  Alamance Community College
#
#             Unnamed: 2     Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0                  NaN            NaN              NaN              NaN
# 1        Student level  Full time Men  Full time Women  Full time Total
# 2  Undergraduate total            678             1059             1737
# 3                    -              -                -                -
# 4   All students total            678             1059             1737
#
#       Unnamed: 6       Unnamed: 7       Unnamed: 8   Unnamed: 9
# ...

# %%
Enrollment_byStudentLevel.columns = ["UnitID", "InstitutionName", "StudentLevel", "FullTimeMen", "FullTimeWomen", "FullTimeTotal", "PartTimeMen", "PartTimeMen", "PartTimeTotal","GrandTotal"]
Enrollment_byStudentLevel = Enrollment_byStudentLevel.drop([0,1], axis = 0)

# %%
Enrollment_byStudentLevel.head()
# Out:
#    UnitID               InstitutionName         StudentLevel FullTimeMen  \
# 2  199786    Alamance Community College  Undergraduate total         678
# 3  199786    Alamance Community College                    -           -
# 4  199786    Alamance Community College   All students total         678
# 5  197869  Appalachian State University  Undergraduate total        7014
# 6  197869  Appalachian State University            Graduate          348
#
#   FullTimeWomen FullTimeTotal PartTimeMen PartTimeMen PartTimeTotal GrandTotal
# 2          1059          1737         863        1736          2599       4336
# 3             -             -           -           -             -          -
# 4          1059          1737         863        1736          2599       4336
# 5          8528         15542         432         621          1053      16595
# 6           597           945         194         561           755       1700

# %% [markdown]
# ## FinancialAid

# %%
FinancialAid = pd.read_csv("FinancialAid.csv")

# %%
FinancialAid.head()
# Out:
#   National Center for Education Statistics                Unnamed: 1  \
# 0                    Student financial aid            selected years
# 1                                   UnitId              Types of aid
# 2                                   197814  College of the Albemarle
# 3                                   197814  College of the Albemarle
# 4                                   197814  College of the Albemarle
#
#                             Unnamed: 2        Unnamed: 3 Unnamed: 4
# 0                                  NaN               NaN        NaN
# 1                                                           2015-16
# 2  First-time full-time undergraduates             Total        238
# 3                              Any aid  Number receiving        160
# 4                       Federal grants  Number receiving        126

# %%
FinancialAid.columns = ["UnitID", "InstitutionName", "AidType", "CountType", "15-16Count"]
FinancialAid = FinancialAid.drop([0,1], axis = 0)

# %%
FinancialAid.head()
# Out:
#    UnitID           InstitutionName                              AidType  \
# 2  197814  College of the Albemarle  First-time full-time undergraduates
# 3  197814  College of the Albemarle                              Any aid
# 4  197814  College of the Albemarle                       Federal grants
# 5  197814  College of the Albemarle                                    -
# 6  197814  College of the Albemarle                   State/Local grants
#
#           CountType 15-16Count
# 2             Total        238
# 3  Number receiving        160
# 4  Number receiving        126
# 5    Average amount       5050
# 6  Number receiving         51

# %% [markdown]
# ## First_Year_Progression
# * SystemTotals

# %%
First_Year_Progression = pd.read_csv("First_Year_Progression.csv")

# %%
First_Year_Progression.head()
# Out:
#              College Name Unnamed: 1 12 HOURS ATTEMPTED\r(Denominator)  \
# 0           System Totals     49,355                            30,766
# 1             Alamance CC      1,160                               748
# 2  Asheville-Buncombe TCC      1,474                               649
# 3      Beaufort County CC        287                               126
# 4               Bladen CC        176                               129
#
#   12 HOURS SUCCESSFUL\r(Numerator)   16-17 15-16 % SUCCESSFUL\r14-15 13-14  \
# 0                           21,401  69.60%   70%                 68%   68%
# 1                              580  77.50%   74%                 71%   75%
# 2                              465  71.60%   70%                 74%   73%
# 3                              100  79.40%   67%                 64%   56%
# 4                               74  57.40%   70%                 69%   60%
#
#   13-Dec
# 0    69%
# 1    70%
# 2    73%
# 3    62%
# 4    57%

# %%
First_Year_Progression.columns = ["InstitutionName", "StudentNum", "12HourAttempt", "12HourSuccess", "PercSuccess16-17", "PercSuccess15-16", "PercSuccess14-15", "PercSuccess13-14", "PercSuccess12-13"]

# %%
First_Year_Progression.head()
# Out:
#           InstitutionName StudentNum 12HourAttempt 12HourSuccess  \
# 0           System Totals     49,355        30,766        21,401
# 1             Alamance CC      1,160           748           580
# 2  Asheville-Buncombe TCC      1,474           649           465
# 3      Beaufort County CC        287           126           100
# 4               Bladen CC        176           129            74
#
#   PercSuccess16-17 PercSuccess15-16 PercSuccess14-15 PercSuccess13-14  \
# 0           69.60%              70%              68%              68%
# 1           77.50%              74%              71%              75%
# 2           71.60%              70%              74%              73%
# 3           79.40%              67%              64%              56%
# 4           57.40%              70%              69%              60%
#
#   PercSuccess12-13
# 0              69%
# 1              70%
# 2              73%
# 3              62%
# 4              57%

# %% [markdown]
# ## First_Year_Progression_Age

# %%
First_Year_Progression_Age = pd.read_csv("First_Year_Progression_Age.csv")

# %%
First_Year_Progression_Age.head()
# Out:
#                Unnamed: 0       -15    16-17 Unnamed: 3 Unnamed: 4        18  \
# 0            College Name  Students  Success   Students    Success  Students
# 1           System Totals     1,098      85%      8,022        76%    12,623
# 2             Alamance CC        55      91%        207        84%       318
# 3  Asheville-Buncombe TCC        16     100%        151        75%       256
# 4      Beaufort County CC        10     100%         55        76%        37
#
#   Unnamed: 6     19-24 Unnamed: 8     25-39 Unnamed: 10       40+ Unnamed: 12
# 0    Success  Students    Success  Students     Success  Students     Success
# 1        67%     6,239        62%     1,946         73%       838         76%
# 2        75%       124        65%        33         85%        11         82%
# 3        69%       136        66%        58         79%        32         75%
# 4        84%        15        80%         6         50%         3           *

# %%
First_Year_Progression_Age.columns = ["InstitutionName", "<=15Num", "<-15Success", "16-17Num", "16-17Success", "18Num", "18Success", "19-24Num", "19-24Success", "25-39Num", "25-39Success", "40+Num", "40+Success"]
First_Year_Progression_Age = First_Year_Progression_Age.drop([0], axis = 0)

# %%
First_Year_Progression_Age.head()
# Out:
#           InstitutionName <=15Num <-15Success 16-17Num 16-17Success   18Num  \
# 1           System Totals   1,098         85%    8,022          76%  12,623
# 2             Alamance CC      55         91%      207          84%     318
# 3  Asheville-Buncombe TCC      16        100%      151          75%     256
# 4      Beaufort County CC      10        100%       55          76%      37
# 5               Bladen CC       5        100%       28          68%      41
#
#   18Success 19-24Num 19-24Success 25-39Num 25-39Success 40+Num 40+Success
# 1       67%    6,239          62%    1,946          73%    838        76%
# 2       75%      124          65%       33          85%     11        82%
# 3       69%      136          66%       58          79%     32        75%
# 4       84%       15          80%        6          50%      3          *
# 5       61%       40          38%       12          67%      3          *

# %% [markdown]
# ## First_Year_Progression_Race

# %%
First_Year_Progression_Race = pd.read_csv("First_Year_Progression_Race.csv")

# %%
First_Year_Progression_Race.head()
# Out:
#                 College Name AFRIC-AMER FEMALE Unnamed: 2 AFRIC-AMERIC MALE  \
# 0                        NaN          Students    Success          Students
# 1              System Totals             3,415        58%             2,665
# 2                Alamance CC                45        73%                49
# 3  Asheville-Buncombe TCC 19               NaN        42%                20
# 4         Beaufort County CC                14        64%                 8
#
#   Unnamed: 4 CAUCASIAN FEMALE Unnamed: 6 CAUCASIAN MALE Unnamed: 8  \
# 0    Success         Students    Success       Students    Success
# 1        49%            8,947        76%          8,341        72%
# 2        65%              250        84%            206        76%
# 3        65%              253        76%            243        72%
# 4        88%               45        78%             34        88%
#
#   HISPANICFEMALE Unnamed: 10 HISPANIC MALE Unnamed: 12 OTHER FEMALE  \
# ...

# %%
First_Year_Progression_Race.columns = ["InstitutionName", "AfricanAmericanFemaleNum", "AfricanAmericanFemaleSuccess", "AfricanAmericanMaleNum", "AfricanAmericanMaleSuccess", "CaucFemaleNum", "CaucFemaleSuccess", "CaucMaleNum", "CaucMaleSuccess", "HispFemaleNum", "HispFemaleSuccess", "HispMaleNum", "HispMaleSuccess", "OtherFemaleNum", "OtherFemaleSuccess", "OtherMaleNum", "OtherMaleSuccess"]
First_Year_Progression_Race = First_Year_Progression_Race.drop([0], axis = 0)

# %%
First_Year_Progression_Race.head()
# Out:
#              InstitutionName AfricanAmericanFemaleNum  \
# 1              System Totals                    3,415
# 2                Alamance CC                       45
# 3  Asheville-Buncombe TCC 19                      NaN
# 4         Beaufort County CC                       14
# 5                  Bladen CC                       16
#
#   AfricanAmericanFemaleSuccess AfricanAmericanMaleNum  \
# 1                          58%                  2,665
# 2                          73%                     49
# 3                          42%                     20
# 4                          64%                      8
# 5                          50%                     12
#
#   AfricanAmericanMaleSuccess CaucFemaleNum CaucFemaleSuccess CaucMaleNum  \
# 1                        49%         8,947               76%       8,341
# 2                        65%           250               84%         206
# 3                        65%           253               76%         243
# ...

# %% [markdown]
# ## License_Cert_Program1
# * Determine variable meanings for all of the License_Cert_Programs

# %%
License_Cert_Program1 = pd.read_csv("License_Cert_Program1.csv")

# %%
License_Cert_Program1.head()
# Out:
#              College Name  Unnamed: 1 AVIATION - GENERAL Unnamed: 3  \
# 0           System Totals        58.0                86%        92%
# 1             Alamance CC         NaN                  *          *
# 2  Asheville-Buncombe TCC         NaN                  *          *
# 3      Beaufort County CC         NaN                  *          *
# 4               Bladen CC         NaN                  *          *
#
#   Unnamed: 4 Unnamed: 5  Unnamed: 6 AVIATION - AIRFRAME Unnamed: 8 Unnamed: 9  \
# 0        90%        97%        49.0                 86%        96%        96%
# 1          *          *         NaN                   *          *          *
# 2          *          *         NaN                   *          *          *
# 3          *          *         NaN                   *          *          *
# 4          *          *         NaN                   *          *          *
#
#       ...     AVIATION - POWER PLANT  Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...

# %% [markdown]
# ## License_Cert_Program2

# %%
License_Cert_Program2 = pd.read_csv("License_Cert_Program2.csv")

# %%
License_Cert_Program2.head()
# Out:
#              College Name  Unnamed: 1 NUC. MED. TECH. Unnamed: 3 Unnamed: 4  \
# 0           System Totals        10.0             80%        59%        78%
# 1             Alamance CC         NaN               *          *          *
# 2  Asheville-Buncombe TCC         NaN               *          *          *
# 3      Beaufort County CC         NaN               *          *          *
# 4               Bladen CC         NaN               *          *          *
#
#   Unnamed: 5  Unnamed: 6 RADIATION THERAPY Unnamed: 8 Unnamed: 9     ...      \
# 0        85%        22.0               82%        71%       100%     ...
# 1          *         NaN                 *          *          *     ...
# 2          *         NaN                 *          *          *     ...
# 3          *         NaN                 *          *          *     ...
# 4          *         NaN                 *          *          *     ...
#
# ...

# %% [markdown]
# ## License_Cert_Program3

# %%
License_Cert_Program3 = pd.read_csv("License_Cert_Program3.csv")

# %%
License_Cert_Program3.head()
# Out:
#              College Name Unnamed: 1 APPRENTICE          Unnamed: 3  \
# 0                     NaN  TEST\r'17        '17  % PASSING\r'16 '15
# 1           System Totals         99        92%                 97%
# 2             Alamance CC          7   86% 100%                 NaN
# 3  Asheville-Buncombe TCC        NaN          *                   *
# 4      Beaufort County CC          1          *                   *
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 COSMETOLOGY          Unnamed: 8 Unnamed: 9  \
# 0        NaN        '14  TEST\r'17         '17  % PASSING\r'16 '15        NaN
# 1        92%        94%        638         85%                 91%        90%
# 2          *       100%         18         89%                 88%        79%
# 3          *          *         11        100%           100% 100%        NaN
# 4          *          *          8         63%            89% 100%        NaN
#
#       ...     Unnamed: 16 INSTRUCTOR         Unnamed: 18 Unnamed: 19  \
# ...

# %% [markdown]
# ## License_Cert_Program4

# %%
License_Cert_Program4 = pd.read_csv("License_Cert_Program4.csv")

# %%
License_Cert_Program4.head()
# Out:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2              BLET**  \
# 0              College Name  TEST\r'17        '17  % PASSING\r'16 '15
# 1             System Totals      1,492        81%                 80%
# 2               Alamance CC         34        82%                 73%
# 3  Asheville-Buncombe TCC46        NaN        89%                 98%
# 4        Beaufort County CC          5        80%                 67%
#
#   Unnamed: 4 Unnamed: 5 DETENTION OFFICER Unnamed: 7          Unnamed: 8  \
# 0        NaN        '14         TEST\r'17        '17  % PASSING\r'16 '15
# 1        82%        82%               745        92%                 92%
# 2        92%        76%                36        81%                 81%
# 3        76%        88%                29       100%      100% 100% 100%
# 4        81%        83%               NaN          *                   *
#
#   Unnamed: 9     ...     Unnamed: 16 EMT-Intermediate         Unnamed: 18  \
# ...

# %% [markdown]
# ## License_Cert_Program5

# %%
License_Cert_Program5 = pd.read_csv("License_Cert_Program5.csv")

# %%
License_Cert_Program5.head()
# Out:
#                  Unnamed: 0 DENTAL HYGIENE** Unnamed: 2          Unnamed: 3  \
# 0              College Name        TEST\r'17        '17  % PASSING\r'16 '15
# 1             System Totals              212        82%                 92%
# 2               Alamance CC              NaN          *                   *
# 3  Asheville-Buncombe TCC14              NaN   71% 100%                 NaN
# 4        Beaufort County CC              NaN          *                   *
#
#   Unnamed: 4 Unnamed: 5 PHYSICAL THERAPIST ASST. Unnamed: 7  \
# 0        NaN        '14                TEST\r'17        '17
# 1        91%        93%                      144        92%
# 2          *          *                      NaN          *
# 3   94% 100%        NaN                      NaN          *
# 4          *          *                      NaN          *
#
#            Unnamed: 8 Unnamed: 9     ...     REGISTERED NURSING Unnamed: 17  \
# ...

# %% [markdown]
# ## Measurable_Skill_Gains_Report
# * Determine variable meanings

# %%
Measurable_Skill_Gains_Report = pd.read_csv("Measurable_Skill_Gains_Report.csv")

# %%
Measurable_Skill_Gains_Report.head()
# Out:
#              College Name Unnamed: 1 ADULT BASIC AND SECONDARY ED  \
# 0                NC Total     80,356                           6%
# 1             Alamance CC       1921                           2%
# 2  Asheville-Buncombe TCC       1970                           7%
# 3      Beaufort County CC        606                           5%
# 4               Bladen CC        355                          10%
#
#     Unnamed: 3   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0           8%  19% 19% 10%        NaN        NaN         6%
# 1           5%  16% 21% 14%        NaN        NaN         7%
# 2           4%  16% 22% 11%        NaN        NaN         5%
# 3  10% 31% 28%          NaN        NaN         9%         7%
# 4           8%  14% 15% 28%        NaN        NaN        20%
#
#   ENGLISH AS A SECOND LANGUAGE Unnamed: 9     ...          Unnamed: 17  \
# 0                           3%         4%     ...          18% 19% 10%
# ...

# %% [markdown]
# ## Performance_Measures_Report
# * System Totals

# %%
Performance_Measures_Report = pd.read_csv("Performance_Measures_Report.csv")

# %%
Performance_Measures_Report.head()
# Out:
#                    College Name Basic Skills Progress Credit English Success  \
# 0       System Excellence Level                68.30%                 55.90%
# 1               System Baseline                34.50%                 23.80%
# 2    Average College Percentage                60.10%                 53.00%
# 3  System Totals (All Students)                58.40%                 55.00%
# 4                   Alamance CC                49.80%                 62.60%
#
#   Credit Math Success First Year Progression Curr Completion Rate  \
# 0              32.50%                 75.00%               51.90%
# 1              10.10%                 54.10%               35.90%
# 2              32.50%                 70.90%               43.40%
# 3              33.80%                 69.60%               43.90%
# 4              41.10%                 77.50%               44.10%
#
#   Licensure Passing Rate Transfer Performance  \
# 0                 90.90%               87.60%
# ...

# %%
Performance_Measures_Report.columns = ["InstitutionName", "BasicSkillsProgress", "CreditEnglishSuccess", "CreditMathSuccess", "FirstYearProgression", "CurrCompletionRate", "LicensurePassingRate", "TransferPerformance", ">=Excellence", ">Average&<Excellence",">Baseline&<Average", "<Baseline"]

# %%
Performance_Measures_Report.head()
# Out:
#                 InstitutionName BasicSkillsProgress CreditEnglishSuccess  \
# 0       System Excellence Level              68.30%               55.90%
# 1               System Baseline              34.50%               23.80%
# 2    Average College Percentage              60.10%               53.00%
# 3  System Totals (All Students)              58.40%               55.00%
# 4                   Alamance CC              49.80%               62.60%
#
#   CreditMathSuccess FirstYearProgression CurrCompletionRate  \
# 0            32.50%               75.00%             51.90%
# 1            10.10%               54.10%             35.90%
# 2            32.50%               70.90%             43.40%
# 3            33.80%               69.60%             43.90%
# 4            41.10%               77.50%             44.10%
#
#   LicensurePassingRate TransferPerformance  >=Excellence  \
# 0               90.90%              87.60%           NaN
# ...

# %% [markdown]
# ## Retention_NationalData

# %%
Retention_NationalData
# Out:
# Empty DataFrame
# Columns: [Table 326.30. Retention of first-time degree-seeking undergraduates at degree-granting postsecondary institutions, by attendance status, level and control of institution, and percentage of applications accepted:
#               Selected years, 2006 to 2016, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20,
# ...

# %% [markdown]
# ## SAT_Scores

# %%
SAT_Scores = pd.read_csv("SAT_Scores.csv")

# %%
SAT_Scores.head()
# Out:
#   National Center for Education Statistics                    Unnamed: 1  \
# 0                 SAT test scores, 2016-17                           NaN
# 1                                   UnitId              Institution name
# 2                                      NaN                           NaN
# 3                                   199786    Alamance Community College
# 4                                   197869  Appalachian State University
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0              NaN              NaN              NaN              NaN
# 1     SAT I Verbal              NaN       SAT I Math              NaN
# 2  25th Percentile  75th Percentile  25th Percentile  75th Percentile
# 3                -                -                -                -
# 4              510              620              520              620
#
#                        Unnamed: 6 Unnamed: 7        Unnamed: 8  Unnamed: 9  \
# ...

# %%
SAT_Scores = pd.DataFrame(SAT_Scores.iloc[:, 0:8])
SAT_Scores.columns = ["UnitID", "InstitutionName", "SAT1Verbal25th", "SAT1Verbal75th", "SAT1Math25th", "SAT1Math75th", "SATStudentNum", "SATStudentPerc"]
SAT_Scores = SAT_Scores.drop([0,1,2], axis = 0)

# %%
SAT_Scores.head()
# Out:
#    UnitID                                 InstitutionName SAT1Verbal25th  \
# 3  199786                      Alamance Community College              -
# 4  197869                    Appalachian State University            510
# 5  197887  Asheville-Buncombe Technical Community College              -
# 6  197966               Beaufort County Community College              -
# 7  198011                        Bladen Community College              -
#
#   SAT1Verbal75th SAT1Math25th SAT1Math75th SATStudentNum SATStudentPerc
# 3              -            -            -             -              -
# 4            620          520          620          1606            51%
# 5              -            -            -             -              -
# 6              -            -            -             -              -
# 7              -            -            -             -              -

# %% [markdown]
# ## Student_Success_English
# * What do these variables mean and what should each column be named?

# %%
Student_Success_English = pd.read_csv("Student_Success_English.csv")

# %%
Student_Success_English.head()
# Out:
#              College Name FALL COHORT\r(Denominator) CRED ENG ENROLLMENT  \
# 0           System Totals                     37,635              26,371
# 1             Alamance CC                        738                 553
# 2  Asheville-Buncombe TCC                        929                 471
# 3      Beaufort County CC                        218                 136
# 4               Bladen CC                        175                 135
#
#   CREDIT ENG SUCCESS\r(Numerator)    2015 % SUCCESSFUL\r2014 2013 Unnamed: 6  \
# 0                          20,704  55.00%                     52%        48%
# 1                             462  62.60%                     58%        57%
# 2                             367  39.50%                     38%        38%
# 3                             108  49.50%                     36%        34%
# 4                              96  54.90%                     61%        40%
#
#   2012
# 0  47%
# 1  50%
# 2  35%
# 3  40%
# 4  30%

# %% [markdown]
# ## Student_Success_Math

# %%
Student_Success_Math = pd.read_csv("Student_Success_Math.csv")

# %%
Student_Success_Math.head()
# Out:
#              College Name FALL COHORT\r(Denominator) CRED MAT ENROLLMENT  \
# 0           System Totals                     37,635              17,137
# 1             Alamance CC                        738                 391
# 2  Asheville-Buncombe TCC                        929                 338
# 3      Beaufort County CC                        218                 121
# 4               Bladen CC                        175                  70
#
#   CREDIT MAT SUCCESS\r(Numerator)    2015 % SUCCESSFUL\r2014 2013 Unnamed: 6  \
# 0                          12,711  33.80%                     30%        28%
# 1                             303  41.10%                     33%        33%
# 2                             262  28.20%                     26%        29%
# 3                             100  45.90%                     28%        29%
# 4                              54  30.90%                     43%        22%
#
#   2012
# 0  26%
# 1  29%
# 2  30%
# 3  32%
# 4  18%

# %% [markdown]
# ## Success_English
# * variable definitions

# %%
Success_English = pd.read_csv("Success_English.csv")

# %%
Success_English.head()
# Out:
#              College Name Students Success Students.1 Success.1 Students.2  \
# 0           System Totals    3,648     41%      9,528       55%     13,596
# 1             Alamance CC        9     89%        201       64%        312
# 2  Asheville-Buncombe TCC      187      6%        209       33%        262
# 3      Beaufort County CC       48     46%         85       49%         46
# 4               Bladen CC        7    100%         39       69%         64
#
#   Success.2 Students.3 Success.3 Students.4 Success.4 Students.5 Success.5
# 0       64%      7,610       49%      2,140       52%      1,113       44%
# 1       69%        164       53%         37       41%         15       47%
# 2       60%        175       46%         66       61%         30       33%
# 3       61%         28       36%          7       43%          4         *
# 4       52%         39       33%         14       64%         12       58%

# %% [markdown]
# ## Success_Math
# * variable definitions

# %%
Success_Math = pd.read_csv("Success_Math.csv")

# %%
Success_Math.head()
# Out:
#              College Name Students Success Students.1 Success.1 Students.2  \
# 0           System Totals    3,648     23%      9,528       44%     13,596
# 1             Alamance CC        9     89%        201       49%        312
# 2  Asheville-Buncombe TCC      187     12%        209       30%        262
# 3      Beaufort County CC       48     46%         85       53%         46
# 4               Bladen CC        7     57%         39       49%         64
#
#   Success.2 Students.3 Success.3 Students.4 Success.4 Students.5 Success.5
# 0       39%      7,610       24%      2,140       21%      1,113       18%
# 1       46%        164       23%         37       30%         15       20%
# 2       38%        175       30%         66       26%         30       23%
# 3       52%         28       14%          7       43%          4         *
# 4       34%         39       13%         14       14%         12       17%
